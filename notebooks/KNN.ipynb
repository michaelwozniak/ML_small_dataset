# %% [markdown]
# # KNN Regression

# %% [markdown]
# KNN in our problem might not be the best choice - variables highly skewed! But we will do our best!

# %% [markdown]
# We will apply following approach in case of KNN:
#  * we will perform feature engineering - standardization
#  * then we will find "good enough" parameters (in CV) to proceed feature selection procedure and after than we will have groups of feature candidates
#  * then we will tune hyperparameters for each group of variables (in CV) - we will obtain couple of models
#  * then we will compare all models based on so called "proper CV" and we will fit and picke the winner!

# %% [markdown]
# We are aware of potential data leakage in case of usage KFold CV without time-series problem handling (in point 2 and 3).
#
# *To be honest in this problem it is not a big deal - based on our experience and we treat it like a feature!*
#
# During the last step of our procedure we will verify previous analysis based on "proper CV" which handle time-series properties!!! So during hyperparameters tuning we will use different CV (we fight against data leakage).

# %% [markdown]
# ### Dependencies loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import RFECV
from sklearn.inspection import permutation_importance
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from ReliefF import ReliefF
import pickle
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 150)

# %% [markdown]
# ### Data loading

# %%
df = pd.read_csv("../data/train_fe.csv", index_col=0)

# %%
fr = pd.read_excel("../data/feature_ranking.xlsx", index_col=0)

# %% [markdown]
# ### Feature engineering for KNN model

# %% [markdown]
# We have to standardize our variables. We will use range standardization (Min Max Scaler) because we have got dummies! We gave every variable a chance to have the same impact on the model.

# %%
print(df.columns.tolist())
# Out:
# ['Ticker', 'Nazwa2', 'rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'ta_log', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'ppent_sqrt', 'intant_sqrt', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
columns = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'ta_log', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'ppent_sqrt', 'intant_sqrt', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
standardization = list()
not_standardization = list()
for i in columns:
    if df[i].nunique() > 2:
        standardization.append(i)
    else:
        not_standardization.append(i)

# %%
print(standardization)
# Out:
# ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'capex2_scaled', 'y_v2x_polyarchy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'ta_log', 'ppent_sqrt', 'intant_sqrt', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'diff_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
print(not_standardization)
# Out:
# ['cfc', 'dta', 'y_e_p_polity', 'y_BR_Democracy', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'adv_expenditure_positive', 'cfc_dta']

# %%
standardization.remove("etr")

# %%
standardization.append("y_e_p_polity")

# %%
print(standardization)
# Out:
# ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'capex2_scaled', 'y_v2x_polyarchy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'ta_log', 'ppent_sqrt', 'intant_sqrt', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'diff_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past', 'y_e_p_polity']

# %%
scaler = MinMaxScaler()
scaler.fit(df[standardization])
df[standardization] = scaler.transform(df[standardization])

# %%
pickle.dump(scaler, open("final_models/minmaxscaler.sav", 'wb'))

# %%
# df[standardization]= scaler.fit_transform(df[standardization])

# %% [markdown]
# Double check. Everything seems to be good :-)

# %%
df[columns].describe().T["min"].unique()
# Out:
# array([0., 1.])

# %%
df[columns].describe().T["max"].unique()
# Out:
# array([1., 1., 1.])

# %% [markdown]
# ### Searching for "good enough" model to feature selection

# %% [markdown]
# Let's use top 10 variables proposed by Mutual Information!

# %%
var = fr.mi_score.sort_values(ascending=False).index.tolist()[0:10]

# %%
print(var)
# Out:
# ['etr_y_past', 'etr_y_ma', 'txt', 'diff', 'ni', 'pi', 'intant', 'intant_sqrt', 'ta', 'dlc']

# %%
df.shape[0]**(0.5)
# Out:
# 63.190189111918315

# %%
param = {"n_neighbors":[5,7,10,12,15,25,40,50,100], "weights": ["uniform", "distance"], "metric":["minkowski", "manhattan", "chebyshev"], "p":[1,2]}

# %%
mse = make_scorer(mean_squared_error, greater_is_better=False)

# %%
model = KNeighborsRegressor()
grid_CV = GridSearchCV(model, param, cv=5, scoring=mse, return_train_score=True, n_jobs=-1)
grid_CV.fit(df.loc[:,var].values, df.loc[:,"etr"].values.ravel())
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=KNeighborsRegressor(algorithm='auto', leaf_size=30,
#                                            metric='minkowski',
#                                            metric_params=None, n_jobs=None,
#                                            n_neighbors=5, p=2,
#                                            weights='uniform'),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'metric': ['minkowski', 'manhattan', 'chebyshev'],
#                          'n_neighbors': [5, 7, 10, 12, 15, 25, 40, 50, 100],
#                          'p': [1, 2], 'weights': ['uniform', 'distance']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=0)

# %%
grid_CV.best_estimator_
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=50, p=1,
#                     weights='uniform')

# %%
grid_CV.cv_results_
# Out:
# {'mean_fit_time': array([0.01259265, 0.01259317, 0.01199236, 0.01159225, 0.01219239,
#         0.01279182, 0.01259208, 0.01199365, 0.01219258, 0.01259203,
#         0.01359119, 0.01399083, 0.01559086, 0.01239247, 0.01319137,
#         0.0119925 , 0.01219277, 0.01259198, 0.01179218, 0.01179233,
#         0.01179194, 0.01219091, 0.01379128, 0.01159315, 0.01239195,
#         0.012991  , 0.01199193, 0.01199217, 0.01239195, 0.01499119,
#         0.01539078, 0.01419106, 0.01399083, 0.01439109, 0.01459088,
#         0.01459146, 0.01499114, 0.01519046, 0.01419172, 0.01499085,
#         0.01439109, 0.01439157, 0.01499071, 0.01479096, 0.01599026,
#         0.01419129, 0.01399126, 0.01479096, 0.01439085, 0.01678934,
#         0.01419158, 0.01459141, 0.01519046, 0.01459117, 0.01578951,
#         0.01439066, 0.01439133, 0.01439104, 0.01898847, 0.01618967,
#         0.01459045, 0.01479063, 0.0143908 , 0.01439056, 0.01419129,
#         0.01519017, 0.01459022, 0.01439123, 0.01559043, 0.01419053,
#         0.01459041, 0.01419153, 0.01479106, 0.0147912 , 0.01439133,
#         0.01499033, 0.01479082, 0.01559062, 0.01439123, 0.01459084,
#         0.01479068, 0.0151907 , 0.01419129, 0.01419106, 0.01459136,
#         0.01439118, 0.01419101, 0.01499057, 0.01439114, 0.01479068,
#         0.01459069, 0.01499019, 0.01439133, 0.01399136, 0.01458998,
#         0.01439066, 0.01539083, 0.0141911 , 0.01499081, 0.01599021,
#         0.01479115, 0.0141911 , 0.01559067, 0.01519022, 0.01559138,
#         0.01479068, 0.01479063, 0.01459084]),
#  'std_fit_time': array([1.74225727e-03, 1.85369976e-03, 6.32560726e-04, 4.90155400e-04,
#         7.47907821e-04, 1.59885909e-03, 1.19936515e-03, 6.32109535e-04,
#         3.99899891e-04, 1.74230651e-03, 2.24362968e-03, 5.01766812e-03,
#         6.34140064e-03, 7.99799200e-04, 1.93822342e-03, 7.59953377e-07,
#         9.79754286e-04, 1.19977013e-03, 3.99590079e-04, 3.99303778e-04,
#         7.48137504e-04, 4.00618779e-04, 3.18716379e-03, 4.89045277e-04,
#         1.35562957e-03, 1.09406001e-03, 6.32034053e-04, 1.09458259e-03,
#         1.01846857e-03, 2.09657916e-03, 1.85392093e-03, 3.99876693e-04,
#         9.09747316e-07, 4.89473229e-04, 4.89805045e-04, 7.99656042e-04,
#         1.09458250e-03, 1.46814043e-03, 7.48239714e-04, 1.67157463e-03,
#         4.89085195e-04, 4.89862696e-04, 1.09458235e-03, 3.99804240e-04,
#         2.52877182e-03, 3.99637379e-04, 3.56832255e-07, 3.99923623e-04,
#         7.99942486e-04, 3.59730721e-03, 3.99732831e-04, 4.89746383e-04,
#         9.79452757e-04, 1.19938893e-03, 3.59714038e-03, 4.90018508e-04,
#         4.89473183e-04, 4.89025754e-04, 7.63764165e-03, 2.31426648e-03,
#         1.19915017e-03, 1.16505103e-03, 4.89706761e-04, 4.89805370e-04,
#         7.48035115e-04, 1.46892590e-03, 7.99632419e-04, 4.89843243e-04,
#         1.74250887e-03, 3.99662383e-04, 4.89999140e-04, 3.99400995e-04,
#         1.16557456e-03, 1.16572158e-03, 4.89376273e-04, 1.54757286e-03,
#         2.13557360e-03, 1.19954780e-03, 4.89453714e-04, 4.90057349e-04,
#         1.59876355e-03, 1.46930843e-03, 3.99995060e-04, 3.98922280e-04,
#         1.19917430e-03, 4.89784837e-04, 4.00018735e-04, 6.31655818e-04,
#         4.89629699e-04, 3.99780444e-04, 4.89745687e-04, 1.09410369e-03,
#         4.89862627e-04, 6.03156597e-07, 4.89745733e-04, 4.90311026e-04,
#         1.01910382e-03, 4.00209612e-04, 6.32032805e-04, 1.09327719e-03,
#         7.47984154e-04, 7.48277330e-04, 2.24330669e-03, 1.46859477e-03,
#         1.19912651e-03, 7.47665787e-04, 4.00114329e-04, 4.90057720e-04]),
#  'mean_score_time': array([0.02158775, 0.02418642, 0.02098699, 0.02338715, 0.02498646,
#         0.0223875 , 0.02318687, 0.02278728, 0.02418642, 0.02638555,
#         0.02918382, 0.02818465, 0.02938404, 0.02678475, 0.02578516,
#         0.02498608, 0.02658448, 0.02678509, 0.02718511, 0.02638531,
#         0.03258276, 0.03478165, 0.04177852, 0.03178163, 0.03657956,
#         0.03797917, 0.03997784, 0.03718066, 0.05077128, 0.0493721 ,
#         0.04997177, 0.04977202, 0.06876082, 0.06916161, 0.07435784,
#         0.07076006, 0.02438636, 0.02578583, 0.02458634, 0.02518592,
#         0.02558527, 0.02858419, 0.02658539, 0.02698488, 0.02938337,
#         0.02918415, 0.02818422, 0.0277844 , 0.03058362, 0.03018341,
#         0.02958345, 0.03018351, 0.03218207, 0.03238149, 0.0321826 ,
#         0.03218207, 0.0377789 , 0.03857894, 0.0369802 , 0.03717952,
#         0.04557481, 0.04417567, 0.04477472, 0.045575  , 0.04997149,
#         0.04857335, 0.04877329, 0.0501718 , 0.06796212, 0.06816187,
#         0.06636257, 0.06876121, 0.02638493, 0.02818456, 0.0273849 ,
#         0.03338118, 0.02818403, 0.02858381, 0.02998304, 0.02878394,
#         0.03178244, 0.03118234, 0.03098254, 0.03098235, 0.03577948,
#         0.03358116, 0.03238196, 0.0335815 , 0.03498006, 0.03438082,
#         0.03558097, 0.0345809 , 0.04057717, 0.04237638, 0.04737396,
#         0.04277754, 0.05117168, 0.04997211, 0.05516953, 0.05636721,
#         0.06456394, 0.05696807, 0.05356998, 0.05596957, 0.08015394,
#         0.07915583, 0.07635646, 0.07635694]),
#  'std_score_time': array([0.00313459, 0.00248008, 0.00218969, 0.00241572, 0.00561839,
#         0.00241531, 0.00278414, 0.00213175, 0.00299161, 0.00508045,
#         0.00584062, 0.00764832, 0.0067671 , 0.00483054, 0.00391754,
#         0.00260672, 0.00241531, 0.00248063, 0.0043056 , 0.00272681,
#         0.00523469, 0.00470395, 0.00906007, 0.00292424, 0.00286897,
#         0.00309621, 0.00357446, 0.00305725, 0.00817801, 0.00407628,
#         0.00540043, 0.00391716, 0.00495306, 0.00359762, 0.00487943,
#         0.00541515, 0.002331  , 0.00511088, 0.00338021, 0.00312219,
#         0.0024159 , 0.00332099, 0.0034389 , 0.00368544, 0.00325974,
#         0.00299125, 0.00248056, 0.00278412, 0.00445124, 0.00336796,
#         0.00300484, 0.00292376, 0.00203835, 0.00185365, 0.00312168,
#         0.00263657, 0.00285546, 0.00382399, 0.00289644, 0.00292421,
#         0.00360946, 0.00336799, 0.00354213, 0.00382356, 0.00433294,
#         0.00371777, 0.0040177 , 0.00667114, 0.00481315, 0.00396732,
#         0.00325996, 0.00483055, 0.00355303, 0.00416421, 0.00205766,
#         0.01133538, 0.00381355, 0.00300466, 0.00489594, 0.00354162,
#         0.00482984, 0.00365317, 0.0046875 , 0.00379247, 0.00772614,
#         0.00458426, 0.00371793, 0.00496085, 0.00424061, 0.0039775 ,
#         0.0055682 , 0.00387492, 0.00402772, 0.00633995, 0.00664695,
#         0.00430506, 0.00292453, 0.0044243 , 0.00764903, 0.00567477,
#         0.02200199, 0.00680775, 0.00515859, 0.00543769, 0.00478774,
#         0.00951066, 0.00722299, 0.00538612]),
#  'param_metric': masked_array(data=['minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'minkowski', 'minkowski', 'minkowski', 'minkowski',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'manhattan', 'manhattan', 'manhattan', 'manhattan',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev',
#                     'chebyshev', 'chebyshev', 'chebyshev', 'chebyshev'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_neighbors': masked_array(data=[5, 5, 5, 5, 7, 7, 7, 7, 10, 10, 10, 10, 12, 12, 12, 12,
#                     15, 15, 15, 15, 25, 25, 25, 25, 40, 40, 40, 40, 50, 50,
#                     50, 50, 100, 100, 100, 100, 5, 5, 5, 5, 7, 7, 7, 7, 10,
#                     10, 10, 10, 12, 12, 12, 12, 15, 15, 15, 15, 25, 25, 25,
#                     25, 40, 40, 40, 40, 50, 50, 50, 50, 100, 100, 100, 100,
#                     5, 5, 5, 5, 7, 7, 7, 7, 10, 10, 10, 10, 12, 12, 12, 12,
#                     15, 15, 15, 15, 25, 25, 25, 25, 40, 40, 40, 40, 50, 50,
#                     50, 50, 100, 100, 100, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_p': masked_array(data=[1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                     2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2,
#                     1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                     2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2,
#                     1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                     2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_weights': masked_array(data=['uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'metric': 'minkowski',
#    'n_neighbors': 5,
#    'p': 1,
#    'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 7, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 7, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 12, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 12, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 12, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 12, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 15, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 15, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 15, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 15, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 25, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 25, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 25, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 25, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 40, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 40, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 40, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 40, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 50, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 50, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 50, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 50, 'p': 2, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 100, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 100, 'p': 1, 'weights': 'distance'},
#   {'metric': 'minkowski', 'n_neighbors': 100, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'minkowski', 'n_neighbors': 100, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 7, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 7, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 12, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 12, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 12, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 12, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 15, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 15, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 15, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 15, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 25, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 25, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 25, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 25, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 40, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 40, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 40, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 40, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 50, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 50, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 50, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 50, 'p': 2, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 100, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 100, 'p': 1, 'weights': 'distance'},
#   {'metric': 'manhattan', 'n_neighbors': 100, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'manhattan', 'n_neighbors': 100, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 7, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 7, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 12, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 12, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 12, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 12, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 15, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 15, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 15, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 15, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 25, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 25, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 25, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 25, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 40, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 40, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 40, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 40, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 50, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 50, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 50, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 50, 'p': 2, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 100, 'p': 1, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 100, 'p': 1, 'weights': 'distance'},
#   {'metric': 'chebyshev', 'n_neighbors': 100, 'p': 2, 'weights': 'uniform'},
#   {'metric': 'chebyshev', 'n_neighbors': 100, 'p': 2, 'weights': 'distance'}],
#  'split0_test_score': array([-0.02010389, -0.02106983, -0.02061573, -0.02148849, -0.01850692,
#         -0.01919326, -0.01863495, -0.01941972, -0.0184076 , -0.01875006,
#         -0.01768232, -0.018214  , -0.01756281, -0.01800941, -0.01752501,
#         -0.01797936, -0.01739173, -0.01770016, -0.01712289, -0.01755653,
#         -0.01656075, -0.01675106, -0.01694398, -0.01717651, -0.01653777,
#         -0.01667372, -0.01672291, -0.01685041, -0.01649871, -0.01661698,
#         -0.01658015, -0.0166957 , -0.01674522, -0.01669974, -0.01677309,
#         -0.01675625, -0.02010389, -0.02106983, -0.02010389, -0.02106983,
#         -0.01850692, -0.01919326, -0.01850692, -0.01919326, -0.0184076 ,
#         -0.01875006, -0.0184076 , -0.01875006, -0.01756281, -0.01800941,
#         -0.01756281, -0.01800941, -0.01739173, -0.01770016, -0.01739173,
#         -0.01770016, -0.01656075, -0.01675106, -0.01656075, -0.01675106,
#         -0.01653777, -0.01667372, -0.01653777, -0.01667372, -0.01649871,
#         -0.01661698, -0.01649871, -0.01661698, -0.01674522, -0.01669974,
#         -0.01674522, -0.01669974, -0.0211367 , -0.02184021, -0.0211367 ,
#         -0.02184021, -0.01995238, -0.0205973 , -0.01995238, -0.0205973 ,
#         -0.01825814, -0.0189753 , -0.01825814, -0.0189753 , -0.01789121,
#         -0.01849529, -0.01789121, -0.01849529, -0.0176985 , -0.01814711,
#         -0.0176985 , -0.01814711, -0.01707583, -0.01735554, -0.01707583,
#         -0.01735554, -0.01662315, -0.01680417, -0.01662315, -0.01680417,
#         -0.0167787 , -0.01688541, -0.0167787 , -0.01688541, -0.01691671,
#         -0.0168992 , -0.01691671, -0.0168992 ]),
#  'split1_test_score': array([-0.0224451 , -0.0225544 , -0.0217165 , -0.02200428, -0.02112614,
#         -0.02135594, -0.02093838, -0.02127107, -0.01985253, -0.02013048,
#         -0.01979165, -0.02013202, -0.01960661, -0.01983009, -0.01925709,
#         -0.01961652, -0.01908895, -0.01932054, -0.01869383, -0.01910943,
#         -0.01845364, -0.01862014, -0.01819655, -0.01852248, -0.01814638,
#         -0.01822563, -0.01801257, -0.01819667, -0.01795762, -0.01806259,
#         -0.01789632, -0.01805463, -0.01779342, -0.01782455, -0.01760851,
#         -0.01770074, -0.0224451 , -0.0225544 , -0.0224451 , -0.0225544 ,
#         -0.02112614, -0.02135594, -0.02112614, -0.02135594, -0.01985253,
#         -0.02013048, -0.01985253, -0.02013048, -0.01960661, -0.01983009,
#         -0.01960661, -0.01983009, -0.01908895, -0.01932054, -0.01908895,
#         -0.01932054, -0.01845364, -0.01862014, -0.01845364, -0.01862014,
#         -0.01814638, -0.01822563, -0.01814638, -0.01822563, -0.01795762,
#         -0.01806259, -0.01795762, -0.01806259, -0.01779342, -0.01782455,
#         -0.01779342, -0.01782455, -0.0218216 , -0.02195374, -0.0218216 ,
#         -0.02195374, -0.02129018, -0.02127425, -0.02129018, -0.02127425,
#         -0.0199896 , -0.02023485, -0.0199896 , -0.02023485, -0.01990314,
#         -0.02012514, -0.01990314, -0.02012514, -0.01931144, -0.01955925,
#         -0.01931144, -0.01955925, -0.01826811, -0.01855476, -0.01826811,
#         -0.01855476, -0.01782389, -0.01805157, -0.01782389, -0.01805157,
#         -0.01774176, -0.01792033, -0.01774176, -0.01792033, -0.01742989,
#         -0.01755002, -0.01742989, -0.01755002]),
#  'split2_test_score': array([-0.02114917, -0.02171514, -0.02119751, -0.0219747 , -0.02073994,
#         -0.02123977, -0.02022198, -0.02092669, -0.0197142 , -0.02026831,
#         -0.01969935, -0.02031006, -0.01957205, -0.01997636, -0.0192751 ,
#         -0.01980151, -0.01886779, -0.01933387, -0.01885662, -0.01938004,
#         -0.01868894, -0.01901826, -0.0188864 , -0.01923521, -0.01878397,
#         -0.01901014, -0.01894064, -0.01917035, -0.0187737 , -0.01894553,
#         -0.01883172, -0.01905031, -0.01871868, -0.01882397, -0.01886001,
#         -0.01897086, -0.02114917, -0.02171514, -0.02114917, -0.02171514,
#         -0.02073994, -0.02123977, -0.02073994, -0.02123977, -0.0197142 ,
#         -0.02026831, -0.0197142 , -0.02026831, -0.01957205, -0.01997636,
#         -0.01957205, -0.01997636, -0.01886779, -0.01933387, -0.01886779,
#         -0.01933387, -0.01868894, -0.01901826, -0.01868894, -0.01901826,
#         -0.01878397, -0.01901014, -0.01878397, -0.01901014, -0.0187737 ,
#         -0.01894553, -0.0187737 , -0.01894553, -0.01871868, -0.01882397,
#         -0.01871868, -0.01882397, -0.02110864, -0.02193703, -0.02110864,
#         -0.02193703, -0.02016626, -0.02102536, -0.02016626, -0.02102536,
#         -0.01993081, -0.02047878, -0.01993081, -0.02047878, -0.01954842,
#         -0.02002102, -0.01954842, -0.02002102, -0.01935588, -0.01980212,
#         -0.01935588, -0.01980212, -0.01908961, -0.01944712, -0.01908961,
#         -0.01944712, -0.01880352, -0.01909898, -0.01880352, -0.01909898,
#         -0.01879873, -0.01904872, -0.01879873, -0.01904872, -0.01889711,
#         -0.019019  , -0.01889711, -0.019019  ]),
#  'split3_test_score': array([-0.02712075, -0.02760919, -0.02762381, -0.0280528 , -0.02610943,
#         -0.02652022, -0.02600702, -0.02653551, -0.02462006, -0.02516889,
#         -0.0247449 , -0.02546607, -0.02423418, -0.02473231, -0.02414795,
#         -0.02485596, -0.02372978, -0.0242676 , -0.02417112, -0.0247635 ,
#         -0.02407977, -0.02435698, -0.02364006, -0.02413287, -0.02385814,
#         -0.02405993, -0.02390631, -0.02413871, -0.02379153, -0.02398563,
#         -0.02395156, -0.02412934, -0.02408264, -0.02407536, -0.02427805,
#         -0.02426039, -0.02712075, -0.02760919, -0.02712075, -0.02760919,
#         -0.02610943, -0.02652022, -0.02610943, -0.02652022, -0.02462006,
#         -0.02516889, -0.02462006, -0.02516889, -0.02423418, -0.02473231,
#         -0.02423418, -0.02473231, -0.02372978, -0.0242676 , -0.02372978,
#         -0.0242676 , -0.02407977, -0.02435698, -0.02407977, -0.02435698,
#         -0.02385814, -0.02405993, -0.02385814, -0.02405993, -0.02379153,
#         -0.02398563, -0.02379153, -0.02398563, -0.02408264, -0.02407536,
#         -0.02408264, -0.02407536, -0.02729838, -0.02815681, -0.02729838,
#         -0.02815681, -0.02630612, -0.02694274, -0.02630612, -0.02694274,
#         -0.02512608, -0.02596318, -0.02512608, -0.02596318, -0.02487165,
#         -0.02559587, -0.02487165, -0.02559587, -0.02430752, -0.02504088,
#         -0.02430752, -0.02504088, -0.02373141, -0.02429196, -0.02373141,
#         -0.02429196, -0.02397418, -0.02429358, -0.02397418, -0.02429358,
#         -0.02405728, -0.0243026 , -0.02405728, -0.0243026 , -0.02401187,
#         -0.02413735, -0.02401187, -0.02413735]),
#  'split4_test_score': array([-0.02546363, -0.02586032, -0.02548728, -0.02600391, -0.0242751 ,
#         -0.02474745, -0.02446491, -0.02486661, -0.02332445, -0.02381198,
#         -0.02392368, -0.02429873, -0.0227854 , -0.02332574, -0.02347188,
#         -0.02389437, -0.0228648 , -0.02324834, -0.02301934, -0.02346061,
#         -0.02212184, -0.02244972, -0.02243737, -0.02269227, -0.02209821,
#         -0.02226012, -0.02206006, -0.02229633, -0.02211577, -0.02221926,
#         -0.0220268 , -0.02221832, -0.02193082, -0.02198058, -0.02195864,
#         -0.02202491, -0.02546363, -0.02586032, -0.02546363, -0.02586032,
#         -0.0242751 , -0.02474745, -0.0242751 , -0.02474745, -0.02332445,
#         -0.02381198, -0.02332445, -0.02381198, -0.0227854 , -0.02332574,
#         -0.0227854 , -0.02332574, -0.0228648 , -0.02324834, -0.0228648 ,
#         -0.02324834, -0.02212184, -0.02244972, -0.02212184, -0.02244972,
#         -0.02209821, -0.02226012, -0.02209821, -0.02226012, -0.02211577,
#         -0.02221926, -0.02211577, -0.02221926, -0.02193082, -0.02198058,
#         -0.02193082, -0.02198058, -0.02629586, -0.02682464, -0.02629586,
#         -0.02682464, -0.02538194, -0.0257054 , -0.02538194, -0.0257054 ,
#         -0.02354205, -0.02408285, -0.02354205, -0.02408285, -0.02334652,
#         -0.02380858, -0.02334652, -0.02380858, -0.0231571 , -0.02357186,
#         -0.0231571 , -0.02357186, -0.02223283, -0.02267674, -0.02223283,
#         -0.02267674, -0.02205661, -0.02232118, -0.02205661, -0.02232118,
#         -0.02201988, -0.02225719, -0.02201988, -0.02225719, -0.02212654,
#         -0.02219769, -0.02212654, -0.02219769]),
#  'mean_test_score': array([-0.02325651, -0.02376178, -0.02332817, -0.02390484, -0.02215151,
#         -0.02261133, -0.02205345, -0.02260392, -0.02118377, -0.02162594,
#         -0.02116838, -0.02168418, -0.02075221, -0.02117478, -0.02073541,
#         -0.02122954, -0.02038861, -0.0207741 , -0.02037276, -0.02085402,
#         -0.01998099, -0.02023923, -0.02002087, -0.02035187, -0.0198849 ,
#         -0.02004591, -0.0199285 , -0.02013049, -0.01982747, -0.019966  ,
#         -0.01985731, -0.02002966, -0.01985416, -0.01988084, -0.01989566,
#         -0.01994263, -0.02325651, -0.02376178, -0.02325651, -0.02376178,
#         -0.02215151, -0.02261133, -0.02215151, -0.02261133, -0.02118377,
#         -0.02162594, -0.02118377, -0.02162594, -0.02075221, -0.02117478,
#         -0.02075221, -0.02117478, -0.02038861, -0.0207741 , -0.02038861,
#         -0.0207741 , -0.01998099, -0.02023923, -0.01998099, -0.02023923,
#         -0.0198849 , -0.02004591, -0.0198849 , -0.02004591, -0.01982747,
#         -0.019966  , -0.01982747, -0.019966  , -0.01985416, -0.01988084,
#         -0.01985416, -0.01988084, -0.02353224, -0.02414249, -0.02353224,
#         -0.02414249, -0.02261938, -0.02310901, -0.02261938, -0.02310901,
#         -0.02136934, -0.02194699, -0.02136934, -0.02194699, -0.02111219,
#         -0.02160918, -0.02111219, -0.02160918, -0.02076609, -0.02122424,
#         -0.02076609, -0.02122424, -0.02007956, -0.02046522, -0.02007956,
#         -0.02046522, -0.01985627, -0.0201139 , -0.01985627, -0.0201139 ,
#         -0.01987927, -0.02008285, -0.01987927, -0.02008285, -0.01987642,
#         -0.01996065, -0.01987642, -0.01996065]),
#  'std_test_score': array([0.00263977, 0.00253376, 0.00274258, 0.00263772, 0.00270192,
#         0.0026451 , 0.00274699, 0.00265729, 0.00236768, 0.00243645,
#         0.00270515, 0.00273781, 0.00241394, 0.00247171, 0.0025984 ,
#         0.00266297, 0.00246082, 0.00252834, 0.00272437, 0.00276289,
#         0.00272336, 0.00276122, 0.00256984, 0.00262488, 0.00268787,
#         0.00271194, 0.00265665, 0.00268988, 0.00270694, 0.00272451,
#         0.00272421, 0.00274127, 0.00273474, 0.00273743, 0.00281124,
#         0.00279651, 0.00263977, 0.00253376, 0.00263977, 0.00253376,
#         0.00270192, 0.0026451 , 0.00270192, 0.0026451 , 0.00236768,
#         0.00243645, 0.00236768, 0.00243645, 0.00241394, 0.00247171,
#         0.00241394, 0.00247171, 0.00246082, 0.00252834, 0.00246082,
#         0.00252834, 0.00272336, 0.00276122, 0.00272336, 0.00276122,
#         0.00268787, 0.00271194, 0.00268787, 0.00271194, 0.00270694,
#         0.00272451, 0.00270694, 0.00272451, 0.00273474, 0.00273743,
#         0.00273474, 0.00273743, 0.00269667, 0.00276637, 0.00269667,
#         0.00276637, 0.0026878 , 0.0026629 , 0.0026878 , 0.0026629 ,
#         0.00254898, 0.00263096, 0.00254898, 0.00263096, 0.00258486,
#         0.00265149, 0.00258486, 0.00265149, 0.00252085, 0.00262074,
#         0.00252085, 0.00262074, 0.00250025, 0.00260351, 0.00250025,
#         0.00260351, 0.00273827, 0.00277775, 0.00273827, 0.00277775,
#         0.00273452, 0.00277502, 0.00273452, 0.00277502, 0.00275207,
#         0.00277559, 0.00275207, 0.00277559]),
#  'rank_test_score': array([ 97, 103, 100, 106,  86,  90,  85,  89,  69,  79,  65,  82,  54,
#          66,  53,  74,  48,  59,  47,  62,  28,  43,  31,  46,  17,  33,
#          21,  42,   1,  25,   9,  32,   4,  14,  20,  22,  97, 103,  97,
#         103,  86,  90,  86,  90,  69,  79,  69,  79,  54,  66,  54,  66,
#          48,  59,  48,  59,  28,  43,  28,  43,  17,  33,  17,  33,   1,
#          25,   1,  25,   4,  14,   4,  14, 101, 107, 101, 107,  93,  95,
#          93,  95,  75,  83,  75,  83,  63,  77,  63,  77,  57,  72,  57,
#          72,  36,  51,  36,  51,   7,  40,   7,  40,  12,  38,  12,  38,
#          10,  23,  10,  23]),
#  'split0_train_score': array([-0.01605275, -0.00053457, -0.01625152, -0.00053457, -0.01733295,
#         -0.00053034, -0.01711301, -0.00053034, -0.01810847, -0.00053032,
#         -0.01810552, -0.00053032, -0.01845843, -0.00053032, -0.01837308,
#         -0.00053032, -0.01871052, -0.00053032, -0.01866307, -0.00053032,
#         -0.01928953, -0.00053032, -0.01927015, -0.00053032, -0.01979394,
#         -0.00053032, -0.01977018, -0.00053032, -0.01991009, -0.00053032,
#         -0.02001127, -0.00053032, -0.02017188, -0.00053032, -0.02025042,
#         -0.00053032, -0.01605275, -0.00053457, -0.01605275, -0.00053457,
#         -0.01733295, -0.00053034, -0.01733295, -0.00053034, -0.01810847,
#         -0.00053032, -0.01810847, -0.00053032, -0.01845843, -0.00053032,
#         -0.01845843, -0.00053032, -0.01871052, -0.00053032, -0.01871052,
#         -0.00053032, -0.01928953, -0.00053032, -0.01928953, -0.00053032,
#         -0.01979394, -0.00053032, -0.01979394, -0.00053032, -0.01991009,
#         -0.00053032, -0.01991009, -0.00053032, -0.02017188, -0.00053032,
#         -0.02017188, -0.00053032, -0.01626202, -0.00053457, -0.01626202,
#         -0.00053457, -0.01758219, -0.00053034, -0.01758219, -0.00053034,
#         -0.01849024, -0.00053032, -0.01849024, -0.00053032, -0.01869415,
#         -0.00053032, -0.01869415, -0.00053032, -0.01888103, -0.00053032,
#         -0.01888103, -0.00053032, -0.01924846, -0.00053032, -0.01924846,
#         -0.00053032, -0.01973407, -0.00053032, -0.01973407, -0.00053032,
#         -0.01989157, -0.00053032, -0.01989157, -0.00053032, -0.02026449,
#         -0.00053032, -0.02026449, -0.00053032]),
#  'split1_train_score': array([-0.01550183, -0.00062192, -0.01560489, -0.00062192, -0.01649204,
#         -0.00061573, -0.01636306, -0.00061573, -0.01753121, -0.00061534,
#         -0.01751682, -0.00061534, -0.01794613, -0.00061533, -0.01782518,
#         -0.00061533, -0.0182906 , -0.00061533, -0.01809603, -0.00061533,
#         -0.01890943, -0.00061533, -0.01892585, -0.00061533, -0.01935706,
#         -0.00061533, -0.01935523, -0.00061533, -0.01956105, -0.00061533,
#         -0.01955394, -0.00061533, -0.0199318 , -0.00061533, -0.02004986,
#         -0.00061533, -0.01550183, -0.00062192, -0.01550183, -0.00062192,
#         -0.01649204, -0.00061573, -0.01649204, -0.00061573, -0.01753121,
#         -0.00061534, -0.01753121, -0.00061534, -0.01794613, -0.00061533,
#         -0.01794613, -0.00061533, -0.0182906 , -0.00061533, -0.0182906 ,
#         -0.00061533, -0.01890943, -0.00061533, -0.01890943, -0.00061533,
#         -0.01935706, -0.00061533, -0.01935706, -0.00061533, -0.01956105,
#         -0.00061533, -0.01956105, -0.00061533, -0.0199318 , -0.00061533,
#         -0.0199318 , -0.00061533, -0.01576552, -0.00062192, -0.01576552,
#         -0.00062192, -0.01682212, -0.00061573, -0.01682212, -0.00061573,
#         -0.01762706, -0.00061534, -0.01762706, -0.00061534, -0.01796273,
#         -0.00061533, -0.01796273, -0.00061533, -0.01834896, -0.00061533,
#         -0.01834896, -0.00061533, -0.01894292, -0.00061533, -0.01894292,
#         -0.00061533, -0.01938518, -0.00061533, -0.01938518, -0.00061533,
#         -0.01955631, -0.00061533, -0.01955631, -0.00061533, -0.02000393,
#         -0.00061533, -0.02000393, -0.00061533]),
#  'split2_train_score': array([-0.01564593, -0.00048906, -0.01566292, -0.00048906, -0.01668808,
#         -0.00047951, -0.01662398, -0.00047951, -0.01747864, -0.00047912,
#         -0.01751974, -0.00047912, -0.01777539, -0.00047912, -0.01770593,
#         -0.00047912, -0.0181536 , -0.00047912, -0.01817288, -0.00047912,
#         -0.01880198, -0.00047912, -0.01872822, -0.00047912, -0.0192555 ,
#         -0.00047912, -0.0191866 , -0.00047912, -0.01926928, -0.00047912,
#         -0.0193559 , -0.00047912, -0.01969521, -0.00047912, -0.01972771,
#         -0.00047912, -0.01564593, -0.00048906, -0.01564593, -0.00048906,
#         -0.01668808, -0.00047951, -0.01668808, -0.00047951, -0.01747864,
#         -0.00047912, -0.01747864, -0.00047912, -0.01777539, -0.00047912,
#         -0.01777539, -0.00047912, -0.0181536 , -0.00047912, -0.0181536 ,
#         -0.00047912, -0.01880198, -0.00047912, -0.01880198, -0.00047912,
#         -0.0192555 , -0.00047912, -0.0192555 , -0.00047912, -0.01926928,
#         -0.00047912, -0.01926928, -0.00047912, -0.01969521, -0.00047912,
#         -0.01969521, -0.00047912, -0.01595867, -0.00048906, -0.01595867,
#         -0.00048906, -0.01694093, -0.00047951, -0.01694093, -0.00047951,
#         -0.01763289, -0.00047912, -0.01763289, -0.00047912, -0.01790777,
#         -0.00047912, -0.01790777, -0.00047912, -0.01823904, -0.00047912,
#         -0.01823904, -0.00047912, -0.0187671 , -0.00047912, -0.0187671 ,
#         -0.00047912, -0.01907457, -0.00047912, -0.01907457, -0.00047912,
#         -0.01924425, -0.00047912, -0.01924425, -0.00047912, -0.01969986,
#         -0.00047912, -0.01969986, -0.00047912]),
#  'split3_train_score': array([-0.01485463, -0.00053136, -0.0147405 , -0.00053136, -0.01574316,
#         -0.0005236 , -0.01577687, -0.0005236 , -0.01647627, -0.00052278,
#         -0.01641733, -0.00052278, -0.01682873, -0.00052278, -0.01664012,
#         -0.00052278, -0.01704778, -0.00052278, -0.01686856, -0.00052278,
#         -0.01759532, -0.00052278, -0.01760979, -0.00052278, -0.01796299,
#         -0.00052278, -0.01795438, -0.00052278, -0.01810907, -0.00052278,
#         -0.01807425, -0.00052278, -0.01844942, -0.00052278, -0.01844111,
#         -0.00052278, -0.01485463, -0.00053136, -0.01485463, -0.00053136,
#         -0.01574316, -0.0005236 , -0.01574316, -0.0005236 , -0.01647627,
#         -0.00052278, -0.01647627, -0.00052278, -0.01682873, -0.00052278,
#         -0.01682873, -0.00052278, -0.01704778, -0.00052278, -0.01704778,
#         -0.00052278, -0.01759532, -0.00052278, -0.01759532, -0.00052278,
#         -0.01796299, -0.00052278, -0.01796299, -0.00052278, -0.01810907,
#         -0.00052278, -0.01810907, -0.00052278, -0.01844942, -0.00052278,
#         -0.01844942, -0.00052278, -0.01476284, -0.00053136, -0.01476284,
#         -0.00053136, -0.01565163, -0.0005236 , -0.01565163, -0.0005236 ,
#         -0.01648504, -0.00052278, -0.01648504, -0.00052278, -0.01672824,
#         -0.00052278, -0.01672824, -0.00052278, -0.01701787, -0.00052278,
#         -0.01701787, -0.00052278, -0.01753435, -0.00052278, -0.01753435,
#         -0.00052278, -0.01785841, -0.00052278, -0.01785841, -0.00052278,
#         -0.01800416, -0.00052278, -0.01800416, -0.00052278, -0.0183828 ,
#         -0.00052278, -0.0183828 , -0.00052278]),
#  'split4_train_score': array([-0.01479273, -0.00057422, -0.01493059, -0.00057422, -0.01592189,
#         -0.00057307, -0.01603922, -0.00057307, -0.01652753, -0.00056836,
#         -0.01673636, -0.00056836, -0.01696498, -0.00056836, -0.0170324 ,
#         -0.00056836, -0.01738539, -0.00056836, -0.01734148, -0.00056836,
#         -0.01807533, -0.00056836, -0.01794918, -0.00056836, -0.01841801,
#         -0.00056836, -0.01846245, -0.00056836, -0.0185599 , -0.00056836,
#         -0.01861737, -0.00056836, -0.01896526, -0.00056836, -0.01898405,
#         -0.00056836, -0.01479273, -0.00057422, -0.01479273, -0.00057422,
#         -0.01592189, -0.00057307, -0.01592189, -0.00057307, -0.01652753,
#         -0.00056836, -0.01652753, -0.00056836, -0.01696498, -0.00056836,
#         -0.01696498, -0.00056836, -0.01738539, -0.00056836, -0.01738539,
#         -0.00056836, -0.01807533, -0.00056836, -0.01807533, -0.00056836,
#         -0.01841801, -0.00056836, -0.01841801, -0.00056836, -0.0185599 ,
#         -0.00056836, -0.0185599 , -0.00056836, -0.01896526, -0.00056836,
#         -0.01896526, -0.00056836, -0.0148814 , -0.00057422, -0.0148814 ,
#         -0.00057422, -0.01601004, -0.00057307, -0.01601004, -0.00057307,
#         -0.01688532, -0.00056836, -0.01688532, -0.00056836, -0.01724444,
#         -0.00056836, -0.01724444, -0.00056836, -0.01753423, -0.00056836,
#         -0.01753423, -0.00056836, -0.01801757, -0.00056836, -0.01801757,
#         -0.00056836, -0.01837681, -0.00056836, -0.01837681, -0.00056836,
#         -0.01848365, -0.00056836, -0.01848365, -0.00056836, -0.01886636,
#         -0.00056836, -0.01886636, -0.00056836]),
#  'mean_train_score': array([-0.01536957, -0.00055023, -0.01543808, -0.00055023, -0.01643562,
#         -0.00054445, -0.01638323, -0.00054445, -0.01722443, -0.00054318,
#         -0.01725915, -0.00054318, -0.01759473, -0.00054318, -0.01751534,
#         -0.00054318, -0.01791758, -0.00054318, -0.0178284 , -0.00054318,
#         -0.01853432, -0.00054318, -0.01849664, -0.00054318, -0.0189575 ,
#         -0.00054318, -0.01894577, -0.00054318, -0.01908188, -0.00054318,
#         -0.01912254, -0.00054318, -0.01944272, -0.00054318, -0.01949063,
#         -0.00054318, -0.01536957, -0.00055023, -0.01536957, -0.00055023,
#         -0.01643562, -0.00054445, -0.01643562, -0.00054445, -0.01722443,
#         -0.00054318, -0.01722443, -0.00054318, -0.01759473, -0.00054318,
#         -0.01759473, -0.00054318, -0.01791758, -0.00054318, -0.01791758,
#         -0.00054318, -0.01853432, -0.00054318, -0.01853432, -0.00054318,
#         -0.0189575 , -0.00054318, -0.0189575 , -0.00054318, -0.01908188,
#         -0.00054318, -0.01908188, -0.00054318, -0.01944272, -0.00054318,
#         -0.01944272, -0.00054318, -0.01552609, -0.00055023, -0.01552609,
#         -0.00055023, -0.01660138, -0.00054445, -0.01660138, -0.00054445,
#         -0.01742411, -0.00054318, -0.01742411, -0.00054318, -0.01770746,
#         -0.00054318, -0.01770746, -0.00054318, -0.01800423, -0.00054318,
#         -0.01800423, -0.00054318, -0.01850208, -0.00054318, -0.01850208,
#         -0.00054318, -0.01888581, -0.00054318, -0.01888581, -0.00054318,
#         -0.01903599, -0.00054318, -0.01903599, -0.00054318, -0.01944349,
#         -0.00054318, -0.01944349, -0.00054318]),
#  'std_train_score': array([4.81354007e-04, 4.48518757e-05, 5.44835299e-04, 4.48518757e-05,
#         5.68425350e-04, 4.63710567e-05, 4.64103451e-04, 4.63710567e-05,
#         6.30187920e-04, 4.58818940e-05, 6.05411264e-04, 4.58818940e-05,
#         6.14073992e-04, 4.58788931e-05, 6.11111336e-04, 4.58788931e-05,
#         6.10471874e-04, 4.58788931e-05, 6.39585500e-04, 4.58788931e-05,
#         6.12385435e-04, 4.58788931e-05, 6.20060387e-04, 4.58788931e-05,
#         6.67561429e-04, 4.58788931e-05, 6.51422860e-04, 4.58788931e-05,
#         6.58708490e-04, 4.58788931e-05, 6.90581935e-04, 4.58788931e-05,
#         6.40191841e-04, 4.58788931e-05, 6.78872451e-04, 4.58788931e-05,
#         4.81354007e-04, 4.48518757e-05, 4.81354007e-04, 4.48518757e-05,
#         5.68425350e-04, 4.63710567e-05, 5.68425350e-04, 4.63710567e-05,
#         6.30187920e-04, 4.58818940e-05, 6.30187920e-04, 4.58818940e-05,
#         6.14073992e-04, 4.58788931e-05, 6.14073992e-04, 4.58788931e-05,
#         6.10471874e-04, 4.58788931e-05, 6.10471874e-04, 4.58788931e-05,
#         6.12385435e-04, 4.58788931e-05, 6.12385435e-04, 4.58788931e-05,
#         6.67561429e-04, 4.58788931e-05, 6.67561429e-04, 4.58788931e-05,
#         6.58708490e-04, 4.58788931e-05, 6.58708490e-04, 4.58788931e-05,
#         6.40191841e-04, 4.58788931e-05, 6.40191841e-04, 4.58788931e-05,
#         5.97362767e-04, 4.48518757e-05, 5.97362767e-04, 4.48518757e-05,
#         6.89594803e-04, 4.63710567e-05, 6.89594803e-04, 4.63710567e-05,
#         6.91891644e-04, 4.58818940e-05, 6.91891644e-04, 4.58818940e-05,
#         6.71131783e-04, 4.58788931e-05, 6.71131783e-04, 4.58788931e-05,
#         6.53692462e-04, 4.58788931e-05, 6.53692462e-04, 4.58788931e-05,
#         6.31332087e-04, 4.58788931e-05, 6.31332087e-04, 4.58788931e-05,
#         6.81056411e-04, 4.58788931e-05, 6.81056411e-04, 4.58788931e-05,
#         6.95109540e-04, 4.58788931e-05, 6.95109540e-04, 4.58788931e-05,
#         7.08801462e-04, 4.58788931e-05, 7.08801462e-04, 4.58788931e-05])}

# %% [markdown]
# Right now (temporary) we will this hyperparameters as the best one:

# %%
grid_CV.best_estimator_
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=50, p=1,
#                     weights='uniform')

# %% [markdown]
# ### Feature selection for KNN

# %% [markdown]
# We would like to base our feature selection on:
#  * feature ranking
#  * forward elimination
#  * relief - special feature selection model for KNN found during Michał Woźniak & Michał Dyczko undergrad. research

# %% [markdown]
# #### Feature ranking

# %%
fr.sort_values("mi_score", ascending=False, inplace=True)

# %%
fr.head()
# Out:
#             mi_score    sign_fscore  sign_fscore_0_1      corr       EN_coef  \
# etr_y_past  1.007860   1.304040e-84                1  0.520405           NaN
# etr_y_ma    0.825573  2.473770e-125                1  0.526827           NaN
# txt         0.633965   5.246456e-13                1  0.368732  1.466269e-05
# diff        0.628929   2.257712e-02                1 -0.291716           NaN
# ni          0.616573   1.747230e-09                1  0.263458 -3.442000e-07
#
#             boruta_rank
# etr_y_past            1
# etr_y_ma              1
# txt                   1
# diff                  1
# ni                    2

# %%
br_features = fr[fr.boruta_rank.isin([1,2,3])].index.tolist()

# %%
mi_features = fr.iloc[0:20].index.tolist()

# %%
mi_features_25 = fr.iloc[0:25].index.tolist()

# %%
mi_features_35 = fr.iloc[0:35].index.tolist()

# %%
mi_features_50 = fr.iloc[0:50].index.tolist()

# %%
fr["corr_abs"] = np.abs(fr["corr"])
fr.sort_values("corr_abs", ascending=False, inplace=True)
corr_features = fr.iloc[0:20].index.tolist()

# %% [markdown]
# We will use our intuition and create two additional benchmark sets of variables:

# %%
benchmark = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
benchmark2 = ['ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'y_v2x_polyarchy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 
              'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %% [markdown]
# #### Forward elimination

# %%
forward_elimination = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'ta_log', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'ppent_sqrt', 'intant_sqrt', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']
forward_elimination.remove("ta_log")
forward_elimination.remove("ppent_sqrt")
forward_elimination.remove("intant_sqrt")
forward_elimination.remove("roa")
forward_elimination.remove("lev")
forward_elimination.remove("intan")
forward_elimination.remove("rd_sqrt")
forward_elimination.remove("ppe")
forward_elimination.remove("cash_holdings_sqrt")

# %%
candidates_withoud_discr = [i for i in forward_elimination if "]" not in i]

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
                    metric_params=None, n_jobs=None, n_neighbors=50, p=1,
                    weights='uniform')

# %%
sf = SFS(model, 
           k_features=(5,15), 
           forward=True, 
           floating=False, 
           verbose=0,
           scoring=mse,
           cv=5)

sffit = sf.fit(df.loc[:,candidates_withoud_discr].values, df.loc[:,"etr"].values.ravel())

sf_features = df.loc[:,candidates_withoud_discr].columns[list(sffit.k_feature_idx_)]

sf_features
# Out:
# Index(['rok', 'str', 'xrd', 'dlc', 'dltt', 'diff', 'y_BR_Democracy',
#        'diff_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'sale_ma'],
#       dtype='object')

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
                    metric_params=None, n_jobs=None, n_neighbors=50, p=1,
                    weights='uniform')

# %%
sf = SFS(model, 
           k_features=(5,15), 
           forward=True, 
           floating=False, 
           verbose=0,
           scoring=mse,
           cv=5, n_jobs=-1)

sffit = sf.fit(df.loc[:,forward_elimination].values, df.loc[:,"etr"].values.ravel())

sf_features2 = df.loc[:,forward_elimination].columns[list(sffit.k_feature_idx_)]

sf_features2
# Out:
# Index(['y_e_p_polity', 'sektor_energy', 'sektor_health care',
#        'sektor_real estate', 'sektor_technology', 'gielda_4',
#        'pi_cat_(-8975.0, -1.523]', 'str_cat_(0.192, 0.28]',
#        'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]',
#        'adv_cat_(874.5, inf]'],
#       dtype='object')

# %%
sf_one_more = ['rok', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta']

# %%
sf = SFS(model, 
           k_features=(5,10), 
           forward=True, 
           floating=False, 
           verbose=0,
           scoring=mse,
           cv=5, n_jobs=-1)

sffit = sf.fit(df.loc[:,sf_one_more].values, df.loc[:,"etr"].values.ravel())

sf_features3 = df.loc[:,sf_one_more].columns[list(sffit.k_feature_idx_)]

sf_features3
# Out:
# Index(['diff', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2'], dtype='object')

# %% [markdown]
# #### Relief

# %%
relief = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'rd', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'ppe_clip', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
fs = ReliefF(n_neighbors=30, n_features_to_keep=5)

# %%
fs.fit(df.loc[:,relief].values, df.loc[:,"etr"].values.ravel())

# %%
relief1 = df.loc[:,relief].iloc[:,fs.top_features[0:10]].columns.tolist()

# %%
relief2 = df.loc[:,relief].iloc[:,fs.top_features[0:15]].columns.tolist()

# %%
relief3 = df.loc[:,relief].iloc[:,fs.top_features[0:20]].columns.tolist()

# %% [markdown]
# ### Hyperparametes Tunning for each group of variables

# %%
param = {"n_neighbors":[5,7,10,12,15,25,40,50], "weights": ["uniform", "distance"], "metric":["minkowski", "manhattan", "chebyshev"], "p":[1,2]}
mse = make_scorer(mean_squared_error, greater_is_better=True)

# %%
def cv_proc(var):
    model = KNeighborsRegressor()
    grid_CV = GridSearchCV(model, param, cv=5, scoring=mse, return_train_score=True, n_jobs=-1)
    grid_CV.fit(df.loc[:,var].values, df.loc[:,"etr"].values.ravel())
    print(grid_CV.best_estimator_)
    print(grid_CV.best_score_)

# %%
cv_proc(benchmark)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='uniform')
# 0.025688847086774234

# %%
cv_proc(benchmark2)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='uniform')
# 0.023681603682248326

# %%
cv_proc(mi_features_25)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.023687438936828415

# %%
cv_proc(mi_features_35)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.024132263841463268

# %%
cv_proc(mi_features_50)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.02408388165995253

# %%
cv_proc(br_features)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='distance')
# 0.021729978128990298

# %%
cv_proc(mi_features)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.023515242037715163

# %%
cv_proc(corr_features)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.023940236434834748

# %%
cv_proc(sf_features)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.022174924760890294

# %%
cv_proc(sf_features2)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='uniform')
# 0.03854412216385179

# %%
cv_proc(sf_features3)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='distance')
# 0.030736984076166145

# %%
cv_proc(relief1)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.02808229700930199

# %%
cv_proc(relief2)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.02782631490123545

# %%
cv_proc(relief3)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                     weights='distance')
# 0.028517759404415605

# %% [markdown]
# ### Final models comparison - winner obtaining

# %% [markdown]
# We would like to fight against data leakage in our CV, so we will treat it like a panel problem with a rolling window. We now based on our experience that this kind of approach is crucial to fight against overfitting.
#
# Sliding window:
#  * T: 2005 - 2008; V: 2009
#  * T: 2005 - 2009; V: 2010
#  * T: 2005 - 2010; V: 2011
#  * ...

# %%
df = df.sort_values(by="rok").reset_index(drop=True)

# %%
def proper_CV(x, y, model, display_res = False):
    train_score = list()
    valid_score = list()
    train_indexes = [0, 1452]
    valid_indexes = [1452, 1815]
    for i in range(0,6):
        train_x =  x[x.index.isin(range(train_indexes[0],train_indexes[1]))]
        train_y =  y[y.index.isin(range(train_indexes[0],train_indexes[1]))]
        valid_x =  x[x.index.isin(range(valid_indexes[0],valid_indexes[1]))]
        valid_y =  y[y.index.isin(range(valid_indexes[0],valid_indexes[1]))]

        model.fit(train_x.values, train_y.values.ravel())
        
        pred_y_train = model.predict(train_x.values)
        rmse = np.sqrt(mean_squared_error(train_y, pred_y_train))
        train_score.append(rmse)

        pred_y_val = model.predict(valid_x.values)
        rmse = np.sqrt(mean_squared_error(valid_y, pred_y_val))
        valid_score.append(rmse)
        
        train_indexes = [0, valid_indexes[1]]
        valid_indexes = [train_indexes[1], valid_indexes[1]+363]
    
    if display_res == True:
        view = pd.DataFrame([train_score, valid_score]).T.rename(columns = {0:"cv_train", 1:"cv_val"})
        display(view)
        return train_score, valid_score, view
    else:
        return train_score, valid_score

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='uniform')
var = benchmark
cv_output0 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.125956  0.151071
# 1  0.123942  0.146469
# 2  0.124273  0.157191
# 3  0.125281  0.148774
# 4  0.124349  0.135068
# 5  0.122619  0.148496

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='uniform')

var = benchmark2
cv_output1 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.123381  0.149848
# 1  0.121944  0.145164
# 2  0.121195  0.157434
# 3  0.122649  0.151020
# 4  0.122394  0.142104
# 5  0.122157  0.147819

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=2,
                    weights='uniform')
var = br_features
cv_output2 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.117684  0.153403
# 1  0.117678  0.136081
# 2  0.115893  0.165368
# 3  0.119046  0.151590
# 4  0.119095  0.135799
# 5  0.117716  0.146451

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = mi_features
cv_output3 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.024271  0.162502
# 1  0.025683  0.143987
# 2  0.028871  0.169731
# 3  0.028130  0.156194
# 4  0.026329  0.130178
# 5  0.025827  0.141895

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='uniform')
var = corr_features
cv_output4 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.123424  0.156191
# 1  0.125023  0.138310
# 2  0.122805  0.157209
# 3  0.123024  0.153019
# 4  0.122702  0.136384
# 5  0.122398  0.145986

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='uniform')
var = sf_features
cv_output5 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.117680  0.157800
# 1  0.116522  0.146221
# 2  0.116989  0.159230
# 3  0.119275  0.150756
# 4  0.119939  0.134568
# 5  0.118065  0.145907

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = sf_features2
cv_output6 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.154031  0.154844
# 1  0.157663  0.152656
# 2  0.156967  0.165148
# 3  0.160991  0.162095
# 4  0.160958  0.155972
# 5  0.160401  0.162150

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = sf_features3
cv_output7 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.028174  0.156305
# 1  0.030226  0.171961
# 2  0.034041  0.169983
# 3  0.032214  0.171439
# 4  0.030203  0.160629
# 5  0.029170  0.155571

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = relief1
cv_output8 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.028174  0.149546
# 1  0.030226  0.155123
# 2  0.033734  0.162585
# 3  0.032146  0.160728
# 4  0.030527  0.142725
# 5  0.029191  0.157520

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = relief2
cv_output9 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.028174  0.158226
# 1  0.030226  0.149294
# 2  0.033435  0.159193
# 3  0.032709  0.156948
# 4  0.030148  0.143187
# 5  0.029186  0.148951

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = relief3 
cv_output10 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.028174  0.161661
# 1  0.030226  0.161281
# 2  0.033404  0.159285
# 3  0.032693  0.163421
# 4  0.030143  0.145755
# 5  0.029224  0.153538

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='chebyshev',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = mi_features_25 
cv_output11 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.024263  0.162663
# 1  0.025652  0.141275
# 2  0.028848  0.164978
# 3  0.027889  0.154550
# 4  0.026176  0.130554
# 5  0.025451  0.141324

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='distance')
var = mi_features_35 
cv_output12 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.023087  0.152087
# 1  0.024506  0.142924
# 2  0.027961  0.156399
# 3  0.027103  0.149464
# 4  0.025429  0.133746
# 5  0.024774  0.137505

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
                    metric_params=None, n_jobs=None, n_neighbors=5, p=1,
                    weights='uniform')
var = mi_features_50 
cv_output13 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.120017  0.143887
# 1  0.120044  0.142002
# 2  0.119194  0.156382
# 3  0.120959  0.150758
# 4  0.120496  0.135599
# 5  0.119601  0.139886

# %%
pd.DataFrame([cv_output0[2].mean().tolist(),
cv_output1[2].mean().tolist(), 
cv_output2[2].mean().tolist(),
cv_output3[2].mean().tolist(),
cv_output4[2].mean().tolist(),
cv_output5[2].mean().tolist(),
cv_output6[2].mean().tolist(),
cv_output7[2].mean().tolist(),
cv_output8[2].mean().tolist(),
cv_output9[2].mean().tolist(),
cv_output10[2].mean().tolist(),
cv_output11[2].mean().tolist(),
cv_output12[2].mean().tolist(),
cv_output13[2].mean().tolist(),], columns=["train_mean", "test_mean"])
# Out:
#     train_mean  test_mean
# 0     0.124403   0.147845
# 1     0.122287   0.148898
# 2     0.117852   0.148115
# 3     0.026519   0.150748
# 4     0.123229   0.147850
# 5     0.118078   0.149080
# 6     0.158502   0.158811
# 7     0.030671   0.164315
# 8     0.030666   0.154705
# 9     0.030646   0.152633
# 10    0.030644   0.157490
# 11    0.026380   0.149224
# 12    0.025477   0.145354
# 13    0.120052   0.144753

# %%
pd.DataFrame([cv_output0[2].std().tolist(),
cv_output1[2].std().tolist(), 
cv_output2[2].std().tolist(),
cv_output3[2].std().tolist(),
cv_output4[2].std().tolist(),
cv_output5[2].std().tolist(),
cv_output6[2].std().tolist(),
cv_output7[2].std().tolist(),
cv_output8[2].std().tolist(),
cv_output9[2].std().tolist(),
cv_output10[2].std().tolist(),
cv_output11[2].std().tolist(),
cv_output12[2].std().tolist(),
cv_output13[2].std().tolist(),], columns=["train_std", "test_std"])
# Out:
#     train_std  test_std
# 0    0.001149  0.007269
# 1    0.000730  0.005282
# 2    0.001173  0.011287
# 3    0.001697  0.014665
# 4    0.000943  0.009053
# 5    0.001316  0.009063
# 6    0.002789  0.004975
# 7    0.002128  0.007688
# 8    0.002010  0.007438
# 9    0.002035  0.006432
# 10   0.002018  0.006686
# 11   0.001690  0.013648
# 12   0.001787  0.008792
# 13   0.000626  0.007578

# %% [markdown]
# 13th models seems to be the best one! We see that our intuition was quite good - binary variables should be removed!

# %%
print(mi_features_50)
# Out:
# ['etr_y_past', 'etr_y_ma', 'txt', 'diff', 'ni', 'pi', 'intant', 'intant_sqrt', 'ta', 'dlc', 'revenue', 'roa_clip', 'roa', 'capex', 'diff_ma', 'ta_log', 'cce', 'dltt', 'intan_past', 'sale', 'intan_ma', 'intan', 'ppent', 'roa_past', 'intan_pow2', 'cash_holdings_sqrt', 'cash_holdings', 'sale_past', 'ppent_sqrt', 'ppe_clip', 'ppe_past', 'roa_ma', 'ppe', 'lev_ma', 'sale_ma', 'capex2', 'cash_holdings_ma', 'capex2_scaled', 'lev_past', 'lev', 'ppe_ma', 'lev_sqrt', 'cash_holdings_past', 'str', 'str_cat_(0.0875, 0.192]', 'WB_GDPpc', 'rr_per_country', 'WB_GDPgrowth', 'WB_Inflation', 'str_cat_(0.28, inf]']

# %% [markdown]
# ### Fit final model and save it

# %%
model = KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
                    metric_params=None, n_jobs=None, n_neighbors=50, p=1,
                    weights='uniform')
model.fit(df.loc[:,mi_features_50].values, df.loc[:,"etr"].values.ravel())
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=50, p=1,
#                     weights='uniform')

# %%
filename = 'final_models/knn.sav'

# %%
pickle.dump(model, open(filename, 'wb'))
