# %% [markdown]
# # SVR

# %% [markdown]
# We will apply following approach in case of SVR:
#  * we will perform feature engineering - standardization
#  * then we will find "good enough" parameters (in CV) to proceed feature selection procedure and after than we will have groups of feature candidates
#  * then we will tune hyperparameters for each group of variables (in CV) - we will obtain couple of models
#  * then we will compare all models based on so called "proper CV" and we will fit and picke the winner!

# %% [markdown]
# We are aware of potential data leakage in case of usage KFold CV without time-series problem handling (in point 2 and 3).
#
# *To be honest in this problem it is not a big deal - based on our experience and we treat it like a feature!*
#
# During the last step of our procedure we will verify previous analysis based on "proper CV" which handle time-series properties!!! So during hyperparameters tuning we will use different CV (we fight against data leakage).

# %% [markdown]
# ### Dependencies loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFECV
from sklearn.inspection import permutation_importance
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
import pickle
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 150)

# %% [markdown]
# ### Data loading

# %%
df = pd.read_csv("../data/train_fe.csv", index_col=0)

# %%
fr = pd.read_excel("../data/feature_ranking.xlsx", index_col=0)

# %% [markdown]
# ### Feature engineering for SVR model

# %% [markdown]
# We have to standardize our variables. We will use z-score standardization!

# %%
print(df.columns.tolist())
# Out:
# ['Ticker', 'Nazwa2', 'rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'ta_log', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'ppent_sqrt', 'intant_sqrt', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
columns = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'ta_log', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'ppent_sqrt', 'intant_sqrt', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
standardization = list()
not_standardization = list()
for i in columns:
    if df[i].nunique() > 2:
        standardization.append(i)
    else:
        not_standardization.append(i)

# %%
print(standardization)
# Out:
# ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'capex2_scaled', 'y_v2x_polyarchy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'ta_log', 'ppent_sqrt', 'intant_sqrt', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'diff_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
print(not_standardization)
# Out:
# ['cfc', 'dta', 'y_e_p_polity', 'y_BR_Democracy', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'adv_expenditure_positive', 'cfc_dta']

# %%
standardization.remove("etr")

# %%
standardization.append("y_e_p_polity")

# %%
print(standardization)
# Out:
# ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'capex2_scaled', 'y_v2x_polyarchy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'ta_log', 'ppent_sqrt', 'intant_sqrt', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'diff_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past', 'y_e_p_polity']

# %%
# df[standardization]= df[standardization].apply(lambda x: (x-x.mean())/x.std())

# %%
scaler = StandardScaler()
scaler.fit(df[standardization])
df[standardization] = scaler.transform(df[standardization])

# %%
pickle.dump(scaler, open("final_models/standardscaler.sav", 'wb'))

# %% [markdown]
# ### Searching for "good enough" model to feature selection

# %%
var = fr.mi_score.sort_values(ascending=False).index.tolist()[0:10]

# %%
print(var)
# Out:
# ['etr_y_past', 'etr_y_ma', 'txt', 'diff', 'ni', 'pi', 'intant', 'intant_sqrt', 'ta', 'dlc']

# %%
param = {"kernel": ["linear", "poly", "rbf", "sigmoid"], "degree":[1,2,3], "C":[0.01, 0.1, 0.25, 0.5, 1, 2, 5, 10], "epsilon":[0.01, 0.1, 0.25, 0.5, 1, 2, 5, 10],"cache_size":[500]}

# %%
mse = make_scorer(mean_squared_error, greater_is_better=False)

# %% [markdown]
# Unfortunately above procedure will take too much time. We have to deal with it :(

# %%
param = {"kernel": ["linear", "poly", "rbf", "sigmoid"] , "degree":[1,2,3]}
model = SVR()
grid_CV = GridSearchCV(model, param, cv=5, scoring=mse, return_train_score=True, n_jobs=-1)
grid_CV.fit(df.loc[:,var].values, df.loc[:,"etr"].values.ravel())
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='scale', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'degree': [1, 2, 3],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=0)

# %%
grid_CV.best_estimator_
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=1, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
kf = KFold(n_splits=5)
rmse_l = list()
rmse_t_l = list()
model = SVR(kernel='linear', tol=0.001, C=1, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

for train, test in kf.split(df.index.values):
    X = df.iloc[train].copy()
    model.fit(X[var].values, X["etr"].values)
    pred_y_train = model.predict(X[var].values)
    rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
    rmse_t_l.append(rmse_t)
    
    pred_y_test = model.predict(df.iloc[test][var].values)
    rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
    rmse_l.append(rmse)
    
#     print(rmse_t, rmse)
    
print(np.mean(rmse_t_l))
print(rmse_t_l)
print(np.mean(rmse_l))
print(rmse_l)
# Out:
# 0.1433031372925931
# [0.14665795080913152, 0.14571158729842426, 0.14408254007380777, 0.1382806864823249, 0.14178292179927723]
# 0.16262199324869844
# [0.13572253974260254, 0.13742897680847274, 0.13967985116486145, 0.24811811898167624, 0.15216047954587922]

# %%
kf = KFold(n_splits=5)
rmse_l = list()
rmse_t_l = list()
model = SVR(kernel='rbf', tol=0.001, C=1, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

for train, test in kf.split(df.index.values):
    X = df.iloc[train].copy()
    model.fit(X[var].values, X["etr"].values)
    pred_y_train = model.predict(X[var].values)
    rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
    rmse_t_l.append(rmse_t)
    
    pred_y_test = model.predict(df.iloc[test][var].values)
    rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
    rmse_l.append(rmse)
    
#     print(rmse_t, rmse)
    
print(np.mean(rmse_t_l))
print(rmse_t_l)
print(np.mean(rmse_l))
print(rmse_l)
# Out:
# 0.13474347821383542
# [0.13990781435823646, 0.13568178578861106, 0.1356158260032889, 0.13032879317504367, 0.13218317174399705]
# 0.14564470965349047
# [0.1304554150184075, 0.14064960462175735, 0.14092970169059332, 0.16349468880140786, 0.1526941381352862]

# %%
kf = KFold(n_splits=5)
rmse_l = list()
rmse_t_l = list()
model = SVR(kernel='poly', tol=0.001, C=1, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

for train, test in kf.split(df.index.values):
    X = df.iloc[train].copy()
    model.fit(X[var].values, X["etr"].values)
    pred_y_train = model.predict(X[var].values)
    rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
    rmse_t_l.append(rmse_t)
    
    pred_y_test = model.predict(df.iloc[test][var].values)
    rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
    rmse_l.append(rmse)
    
#     print(rmse_t, rmse)
    
print(np.mean(rmse_t_l))
print(rmse_t_l)
print(np.mean(rmse_l))
print(rmse_l)
# Out:
# 0.14191829816456672
# [0.1459682683041094, 0.14267689836032438, 0.14362450179256392, 0.13744036445328045, 0.13988145791255552]
# 2.883509288354514
# [0.9223928793979164, 6.39234310833795, 0.1780590164280294, 6.750395040517739, 0.1743563970909365]

# %%
kf = KFold(n_splits=5)
rmse_l = list()
rmse_t_l = list()
model = SVR(kernel='poly',degree = 3 ,tol=0.001, C=1, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

for train, test in kf.split(df.index.values):
    X = df.iloc[train].copy()
    model.fit(X[var].values, X["etr"].values)
    pred_y_train = model.predict(X[var].values)
    rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
    rmse_t_l.append(rmse_t)
    
    pred_y_test = model.predict(df.iloc[test][var].values)
    rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
    rmse_l.append(rmse)
    
#     print(rmse_t, rmse)
    
print(np.mean(rmse_t_l))
print(rmse_t_l)
print(np.mean(rmse_l))
print(rmse_l)
# Out:
# 0.14191829816456672
# [0.1459682683041094, 0.14267689836032438, 0.14362450179256392, 0.13744036445328045, 0.13988145791255552]
# 2.883509288354514
# [0.9223928793979164, 6.39234310833795, 0.1780590164280294, 6.750395040517739, 0.1743563970909365]

# %%
kf = KFold(n_splits=5)
rmse_l = list()
rmse_t_l = list()
model = SVR(kernel='sigmoid', tol=0.001, C=1, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

for train, test in kf.split(df.index.values):
    X = df.iloc[train].copy()
    model.fit(X[var].values, X["etr"].values)
    pred_y_train = model.predict(X[var].values)
    rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
    rmse_t_l.append(rmse_t)
    
    pred_y_test = model.predict(df.iloc[test][var].values)
    rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
    rmse_l.append(rmse)
    
#     print(rmse_t, rmse)
    
print(np.mean(rmse_t_l))
print(rmse_t_l)
print(np.mean(rmse_l))
print(rmse_l)
# Out:
# 38.11016651212357
# [42.782100294868194, 39.41926145896053, 41.296757022952214, 37.2532590255031, 29.799454758333813]
# 33.93442091141098
# [44.80174185074988, 35.97429487496919, 20.290968950153605, 46.98136867652167, 21.62373020466057]

# %% [markdown]
# We see that results from sklearn gridsearch and our own procedure of CV are the same!

# %% [markdown]
# Let's build such a intuition in case of parameters for C and epsilon.

# %%
for c in [0.01, 0.1, 0.25, 0.5, 1, 2, 5, 10]:
    kf = KFold(n_splits=5)
    rmse_l = list()
    rmse_t_l = list()
    model = SVR(kernel='rbf', tol=0.001, C=c, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

    for train, test in kf.split(df.index.values):
        X = df.iloc[train].copy()
        model.fit(X[var].values, X["etr"].values)
        pred_y_train = model.predict(X[var].values)
        rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
        rmse_t_l.append(rmse_t)

        pred_y_test = model.predict(df.iloc[test][var].values)
        rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
        rmse_l.append(rmse)

    #     print(rmse_t, rmse)
    print(c)
    print(np.mean(rmse_t_l))
    print(rmse_t_l)
    print(np.mean(rmse_l))
    print(rmse_l)
    print("\n")
# Out:
# 0.01
# 0.141854981161431
# [0.14507055655160625, 0.14366587832849181, 0.1426142511431801, 0.1383535853137582, 0.1395706344701187]
# 0.14266560000648204
# [0.1309112638193132, 0.13587587861957426, 0.13728612697945855, 0.1578324181348141, 0.15142231247925023]
#
#
# 0.1
# 0.1397880031594139
# [0.14349156067669067, 0.1414114868703918, 0.14049303621832046, 0.1361100441563734, 0.1374338878752931]
# 0.14357862629065077
# [0.1323187210217905, 0.13672942502548058, 0.13878758030996718, 0.15872536203135815, 0.15133204306465742]
#
#
# 0.25
# 0.13804255932848603
# [0.1422760138927239, 0.13930876449241622, 0.1387895337041885, 0.13403499895175988, 0.1358034856013416]
# 0.14387449906589092
# [0.1315033184683226, 0.13716519217688103, 0.13922413367084854, 0.15975389112076807, 0.15172595989263427]
#
#
# 0.5
# 0.13639169895068717
# [0.14101245308977237, 0.1372655346087332, 0.1372516008628544, 0.13215881207038213, 0.13427009412169372]
# 0.14455775415152008
# [0.13067234392309998, 0.13856112758100916, 0.1393631868883453, 0.16175901052425093, 0.15243310184089512]
#
#
# 1
# 0.13474347821383542
# [0.13990781435823646, 0.13568178578861106, 0.1356158260032889, 0.13032879317504367, 0.13218317174399705]
# 0.14564470965349047
# [0.1304554150184075, 0.14064960462175735, 0.14092970169059332, 0.16349468880140786, 0.1526941381352862]
#
#
# 2
# 0.1332250632372111
# [0.13841851508333436, 0.13433088791315212, 0.1339710060410839, 0.12898773314519305, 0.130417174003292]
# 0.14653706466605762
# [0.12988706743303172, 0.1420716210327638, 0.14240575021539006, 0.16530792605828543, 0.15301295859081707]
#
#
# 5
# 0.13123497439124254
# [0.13615546893677227, 0.13266817537993345, 0.13229386756131623, 0.12679969321276383, 0.12825766686542697]
# 0.14812833532689082
# [0.1289210081658241, 0.14433660574560042, 0.1440511604342551, 0.16887047636056365, 0.15446242592821077]
#
#
# 10
# 0.12987341990494955
# [0.1345300228811481, 0.13140473619071968, 0.13106421737084814, 0.1253903003723004, 0.12697782270973135]
# 0.14900344238265859
# [0.12807930766589085, 0.14566367841077552, 0.1447094894955343, 0.17165003198734974, 0.15491470435374252]

# %% [markdown]
# Lower better!

# %%
for c in [0.0001, 0.001,0.005,0.007,0.01]:
    kf = KFold(n_splits=5)
    rmse_l = list()
    rmse_t_l = list()
    model = SVR(kernel='rbf', tol=0.001, C=c, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

    for train, test in kf.split(df.index.values):
        X = df.iloc[train].copy()
        model.fit(X[var].values, X["etr"].values)
        pred_y_train = model.predict(X[var].values)
        rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
        rmse_t_l.append(rmse_t)

        pred_y_test = model.predict(df.iloc[test][var].values)
        rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
        rmse_l.append(rmse)

    #     print(rmse_t, rmse)
    print(c)
    print(np.mean(rmse_t_l))
    print(rmse_t_l)
    print(np.mean(rmse_l))
    print(rmse_l)
    print("\n")
# Out:
# 0.0001
# 0.15204155284890247
# [0.15422249391825393, 0.15386680892406673, 0.15394950367143756, 0.1489066338398744, 0.1492623238908797]
# 0.15198982006200942
# [0.1443541326288839, 0.1471707501007815, 0.14074140832613885, 0.16403841088534588, 0.16364439836889694]
#
#
# 0.001
# 0.1451467235033977
# [0.14804708344905568, 0.14721042583467545, 0.1462142050603316, 0.14157587642578578, 0.14268602674713993]
# 0.1452886652397471
# [0.1354131166641112, 0.13994132591918104, 0.13687360846670707, 0.1589524212301061, 0.15526285391863]
#
#
# 0.005
# 0.14232290803643588
# [0.1457014623594707, 0.14408950346237664, 0.1431395274596324, 0.13871819668047183, 0.13996585022022773]
# 0.14285494288986966
# [0.13155930132951124, 0.13601794440636522, 0.13702446373586172, 0.15773362112591519, 0.15193938385169492]
#
#
# 0.007
# 0.14209768666632913
# [0.14535786041323126, 0.14391355457912236, 0.1428748746248252, 0.13852102307893838, 0.13982112063552843]
# 0.14276713144355374
# [0.13115153786519929, 0.13593863034261544, 0.1371715192890003, 0.15780398619477864, 0.1517699835261751]
#
#
# 0.01
# 0.141854981161431
# [0.14507055655160625, 0.14366587832849181, 0.1426142511431801, 0.1383535853137582, 0.1395706344701187]
# 0.14266560000648204
# [0.1309112638193132, 0.13587587861957426, 0.13728612697945855, 0.1578324181348141, 0.15142231247925023]

# %%
for e in [0.01, 0.1, 0.25, 0.5, 1, 2, 5, 10]:
    kf = KFold(n_splits=5)
    rmse_l = list()
    rmse_t_l = list()
    model = SVR(kernel='rbf', tol=0.001, C=0.01, epsilon=e, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

    for train, test in kf.split(df.index.values):
        X = df.iloc[train].copy()
        model.fit(X[var].values, X["etr"].values)
        pred_y_train = model.predict(X[var].values)
        rmse_t = np.sqrt(mean_squared_error(df.iloc[train]["etr"].values, pred_y_train))
        rmse_t_l.append(rmse_t)

        pred_y_test = model.predict(df.iloc[test][var].values)
        rmse = np.sqrt(mean_squared_error(df.iloc[test]["etr"].values, pred_y_test))
        rmse_l.append(rmse)

    #     print(rmse_t, rmse)
    print(e)
    print(np.mean(rmse_t_l))
    print(rmse_t_l)
    print(np.mean(rmse_l))
    print(rmse_l)
    print("\n")
# Out:
# 0.01
# 0.14128340864781455
# [0.14507743354559027, 0.14338590816254743, 0.14223030178000004, 0.13707907549727982, 0.1386443242536551]
# 0.14209536837429512
# [0.12939177658485884, 0.13548397284521965, 0.13823194307018954, 0.15701942515028666, 0.15034972422092094]
#
#
# 0.1
# 0.141854981161431
# [0.14507055655160625, 0.14366587832849181, 0.1426142511431801, 0.1383535853137582, 0.1395706344701187]
# 0.14266560000648204
# [0.1309112638193132, 0.13587587861957426, 0.13728612697945855, 0.1578324181348141, 0.15142231247925023]
#
#
# 0.25
# 0.1567650515603481
# [0.15894111903550812, 0.15904516898108081, 0.15776127910107826, 0.15382258708531588, 0.15425510359875738]
# 0.15684915373193972
# [0.1486996521804123, 0.14740458625763989, 0.1514943147090381, 0.1678028123593834, 0.1688444031532249]
#
#
# 0.5
# 0.32388509719541736
# [0.32520531078076087, 0.3270158248991175, 0.321673546723654, 0.3229354409860673, 0.32259536258748694]
# 0.3237976943652258
# [0.318581990984175, 0.31108522709285497, 0.33260676521270166, 0.32768804201378193, 0.3290264465226155]
#
#
# 1
# 0.32388509719541736
# [0.32520531078076087, 0.3270158248991175, 0.321673546723654, 0.3229354409860673, 0.32259536258748694]
# 0.3237976943652258
# [0.318581990984175, 0.31108522709285497, 0.33260676521270166, 0.32768804201378193, 0.3290264465226155]
#
#
# 2
# 0.32388509719541736
# [0.32520531078076087, 0.3270158248991175, 0.321673546723654, 0.3229354409860673, 0.32259536258748694]
# 0.3237976943652258
# [0.318581990984175, 0.31108522709285497, 0.33260676521270166, 0.32768804201378193, 0.3290264465226155]
#
#
# 5
# 0.32388509719541736
# [0.32520531078076087, 0.3270158248991175, 0.321673546723654, 0.3229354409860673, 0.32259536258748694]
# 0.3237976943652258
# [0.318581990984175, 0.31108522709285497, 0.33260676521270166, 0.32768804201378193, 0.3290264465226155]
#
#
# 10
# 0.32388509719541736
# [0.32520531078076087, 0.3270158248991175, 0.321673546723654, 0.3229354409860673, 0.32259536258748694]
# 0.3237976943652258
# [0.318581990984175, 0.31108522709285497, 0.33260676521270166, 0.32768804201378193, 0.3290264465226155]

# %% [markdown]
# Our quasi final model for this procedure:

# %%
model = SVR(kernel='rbf', C=0.01, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

# %% [markdown]
# ### Feature selection for SVR

# %% [markdown]
# We would like to base our feature selection on:
#  * feature ranking
#  * forward elimination
#  * recursive feature elimination - using "linear" kernel

# %% [markdown]
# #### Feature ranking

# %%
fr.sort_values("mi_score", ascending=False, inplace=True)

# %%
fr.head()
# Out:
#             mi_score    sign_fscore  sign_fscore_0_1      corr       EN_coef  \
# etr_y_past  1.007860   1.304040e-84                1  0.520405           NaN
# etr_y_ma    0.825573  2.473770e-125                1  0.526827           NaN
# txt         0.633965   5.246456e-13                1  0.368732  1.466269e-05
# diff        0.628929   2.257712e-02                1 -0.291716           NaN
# ni          0.616573   1.747230e-09                1  0.263458 -3.442000e-07
#
#             boruta_rank
# etr_y_past            1
# etr_y_ma              1
# txt                   1
# diff                  1
# ni                    2

# %%
br_features = fr[fr.boruta_rank.isin([1,2,3])].index.tolist()

# %%
mi_features = fr.iloc[0:20].index.tolist()

# %%
mi_features_25 = fr.iloc[0:25].index.tolist()

# %%
mi_features_35 = fr.iloc[0:35].index.tolist()

# %%
mi_features_50 = fr.iloc[0:50].index.tolist()

# %%
fr["corr_abs"] = np.abs(fr["corr"])
fr.sort_values("corr_abs", ascending=False, inplace=True)
corr_features = fr.iloc[0:20].index.tolist()

# %% [markdown]
# We will use our intuition and create two additional benchmark sets of variables:

# %%
benchmark = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
benchmark2 = ['ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'etr', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'y_v2x_polyarchy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 
              'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %% [markdown]
# #### Forward elimination

# %%
forward_elimination = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'ta_log', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'ppent_sqrt', 'intant_sqrt', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']
forward_elimination.remove("ta_log")
forward_elimination.remove("ppent_sqrt")
forward_elimination.remove("intant_sqrt")
forward_elimination.remove("roa")
forward_elimination.remove("lev")
forward_elimination.remove("intan")
forward_elimination.remove("rd_sqrt")
forward_elimination.remove("ppe")
forward_elimination.remove("cash_holdings_sqrt")

# %%
candidates_withoud_discr = [i for i in forward_elimination if "]" not in i]

# %%
model = SVR(kernel='rbf', C=0.01, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

# %%
sf = SFS(model, 
           k_features=(5,20), 
           forward=True, 
           floating=False, 
           verbose=0,
           scoring=mse,
           cv=5,n_jobs=-1)

sffit = sf.fit(df.loc[:,candidates_withoud_discr].values, df.loc[:,"etr"].values.ravel())

sf_features = df.loc[:,candidates_withoud_discr].columns[list(sffit.k_feature_idx_)]

sf_features
# Out:
# Index(['ta', 'cce', 'diff', 'sale', 'cfc', 'y_BR_Democracy', 'WB_GDPgrowth',
#        'WB_Inflation', 'sektor_consumer discretionary', 'sektor_industrials',
#        'sektor_utilities', 'gielda_3', 'gielda_4', 'gielda_5', 'diff_positive',
#        'adv_expenditure_positive', 'diff_dta', 'etr_y_past', 'etr_y_ma',
#        'diff_ma'],
#       dtype='object')

# %%
model = SVR(kernel='rbf', C=0.01, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)

# %%
sf = SFS(model, 
           k_features=(5,20), 
           forward=True, 
           floating=False, 
           verbose=0,
           scoring=mse,
           cv=5,n_jobs=-1)

sffit = sf.fit(df.loc[:,forward_elimination].values, df.loc[:,"etr"].values.ravel())

sf_features2 = df.loc[:,forward_elimination].columns[list(sffit.k_feature_idx_)]

sf_features2
# Out:
# Index(['diff', 'cfc', 'WB_GDPgrowth', 'WB_Inflation', 'sektor_industrials',
#        'sektor_materials', 'sektor_utilities', 'txt_cat_(-63.011, -34.811]',
#        'pi_cat_(-8975.0, -1.523]', 'pi_cat_(8108.5, inf]',
#        'str_cat_(0.28, inf]', 'dlc_cat_(42.262, 176.129]',
#        'dlc_cat_(176.129, 200.9]', 'capex_cat_(5451.0, inf]',
#        'revenue_cat_(0.174, 1248.817]', 'adv_cat_(0.3, 874.5]',
#        'diff_positive', 'etr_y_past', 'etr_y_ma', 'diff_ma'],
#       dtype='object')

# %% [markdown]
# Ten hours later!

# %% [markdown]
# #### Recursive Feature Elimination

# %%
rfe_candidates = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'roa', 'lev', 'intan', 'rd', 'ppe', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'ta_log', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'ppent_sqrt', 'intant_sqrt', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'rd_sqrt', 'ppe_clip', 'cash_holdings_sqrt', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']
rfe_candidates.remove("ta_log")
rfe_candidates.remove("ppent_sqrt")
rfe_candidates.remove("intant_sqrt")
rfe_candidates.remove("roa")
rfe_candidates.remove("lev")
rfe_candidates.remove("intan")
rfe_candidates.remove("rd_sqrt")
rfe_candidates.remove("ppe")
rfe_candidates.remove("cash_holdings_sqrt")

# %%
rfe_candidates_without_disc = [i for i in rfe_candidates if "]" not in i]

# %%
estimator = SVR(kernel='linear', C=0.01, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)
selector = RFECV(estimator, step=1, cv=5,min_features_to_select=7, n_jobs=-1)
selector = selector.fit(df.loc[:,rfe_candidates_without_disc].values, df.loc[:,"etr"].values.ravel())

# %%
df.loc[:,rfe_candidates_without_disc].iloc[:,selector.support_].columns.tolist()
# Out:
# ['rok',
#  'ta',
#  'txt',
#  'pi',
#  'str',
#  'xrd',
#  'ni',
#  'ppent',
#  'intant',
#  'dlc',
#  'capex',
#  'revenue',
#  'cce',
#  'adv',
#  'diff',
#  'rd',
#  'sale',
#  'cash_holdings',
#  'adv_expenditure',
#  'capex2',
#  'cfc',
#  'dta',
#  'capex2_scaled',
#  'y_v2x_polyarchy',
#  'y_e_p_polity',
#  'WB_GDPgrowth',
#  'WB_GDPpc',
#  'WB_Inflation',
#  'rr_per_country',
#  'rr_per_sector',
#  'sektor_consumer discretionary',
#  'sektor_consumer staples',
#  'sektor_energy',
#  'sektor_health care',
#  'sektor_industrials',
#  'sektor_materials',
#  'sektor_real estate',
#  'sektor_technology',
#  'sektor_utilities',
#  'gielda_2',
#  'gielda_3',
#  'gielda_4',
#  'gielda_5',
#  'xrd_exists',
#  'ni_profit',
#  'ni_profit_20000',
#  'diff_positive',
#  'roa_clip',
#  'lev_sqrt',
#  'intan_pow2',
#  'ppe_clip',
#  'adv_expenditure_positive',
#  'diff_dta',
#  'cfc_dta',
#  'etr_y_past',
#  'etr_y_ma',
#  'diff_ma',
#  'roa_ma',
#  'lev_ma',
#  'intan_ma',
#  'ppe_ma',
#  'sale_ma',
#  'roa_past',
#  'lev_past',
#  'intan_past',
#  'ppe_past',
#  'sale_past',
#  'cash_holdings_past']

# %%
rfe_candidates_without_disc = df.loc[:,rfe_candidates_without_disc].iloc[:,selector.support_].columns.tolist()

# %%
estimator = SVR(kernel='linear', C=0.01, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)
selector = RFECV(estimator, step=1, cv=5,min_features_to_select=7,n_jobs=-1)
selector = selector.fit(df.loc[:,rfe_candidates].values, df.loc[:,"etr"].values.ravel())

# %%
df.loc[:,rfe_candidates].iloc[:,selector.support_].columns.tolist()
# Out:
# ['ni',
#  'revenue',
#  'capex2',
#  'cfc',
#  'capex2_scaled',
#  'sektor_consumer discretionary',
#  'sektor_industrials',
#  'sektor_materials',
#  'gielda_5',
#  'txt_cat_(-63.011, -34.811]',
#  'txt_cat_(-34.811, 0.488]',
#  'txt_cat_(0.488, 24.415]',
#  'txt_cat_(25.05, 308.55]',
#  'txt_cat_(308.55, 327.531]',
#  'txt_cat_(327.531, inf]',
#  'pi_cat_(-8975.0, -1.523]',
#  'pi_cat_(7875.5, 8108.5]',
#  'str_cat_(0.28, inf]',
#  'ni_profit_20000',
#  'dlc_cat_(42.262, 176.129]',
#  'dlc_cat_(176.129, 200.9]',
#  'dlc_cat_(200.9, inf]',
#  'capex_cat_(5451.0, inf]',
#  'revenue_cat_(0.174, 1248.817]',
#  'revenue_cat_(1248.817, 4233.587]',
#  'adv_cat_(0.3, 874.5]',
#  'adv_cat_(874.5, inf]',
#  'diff_positive',
#  'etr_y_ma']

# %%
rfe_candidates = df.loc[:,rfe_candidates].iloc[:,selector.support_].columns.tolist()

# %% [markdown]
# #### Permutation importance

# %% [markdown]
# Let's try something new for us - permutation importance for feature selection.

# %%
pi_candidates = ['rok', 'ta', 'txt', 'pi', 'str', 'xrd', 'ni', 'ppent', 'intant', 'dlc', 'dltt', 'capex', 'revenue', 'cce', 'adv', 'diff', 'rd', 'sale', 'cash_holdings', 'adv_expenditure', 'capex2', 'cfc', 'dta', 'capex2_scaled', 'y_v2x_polyarchy', 'y_e_p_polity', 'y_BR_Democracy', 'WB_GDPgrowth', 'WB_GDPpc', 'WB_Inflation', 'rr_per_country', 'rr_per_sector', 'sektor_consumer discretionary', 'sektor_consumer staples', 'sektor_energy', 'sektor_health care', 'sektor_industrials', 'sektor_materials', 'sektor_real estate', 'sektor_technology', 'sektor_utilities', 'gielda_2', 'gielda_3', 'gielda_4', 'gielda_5', 'txt_cat_(-63.011, -34.811]', 'txt_cat_(-34.811, 0.488]', 'txt_cat_(0.488, 24.415]', 'txt_cat_(24.415, 25.05]', 'txt_cat_(25.05, 308.55]', 'txt_cat_(308.55, 327.531]', 'txt_cat_(327.531, inf]', 'pi_cat_(-8975.0, -1.523]', 'pi_cat_(-1.523, 157.119]', 'pi_cat_(157.119, 465.9]', 'pi_cat_(465.9, 7875.5]', 'pi_cat_(7875.5, 8108.5]', 'pi_cat_(8108.5, inf]', 'str_cat_(0.0875, 0.192]', 'str_cat_(0.192, 0.28]', 'str_cat_(0.28, inf]', 'xrd_exists', 'ni_profit', 'ni_profit_20000', 'dlc_cat_(42.262, 176.129]', 'dlc_cat_(176.129, 200.9]', 'dlc_cat_(200.9, inf]', 'dltt_cat_(39.38, 327.85]', 'dltt_cat_(327.85, 876.617]', 'dltt_cat_(876.617, inf]', 'capex_cat_(7.447, 79.55]', 'capex_cat_(79.55, 5451.0]', 'capex_cat_(5451.0, inf]', 'revenue_cat_(0.174, 1248.817]', 'revenue_cat_(1248.817, 4233.587]', 'revenue_cat_(4233.587, inf]', 'cce_cat_(5.619, 63.321]', 'cce_cat_(63.321, inf]', 'adv_cat_(0.3, 874.5]', 'adv_cat_(874.5, inf]', 'diff_positive', 'roa_clip', 'lev_sqrt', 'intan_pow2', 'ppe_clip', 'adv_expenditure_positive', 'diff_dta', 'cfc_dta', 'etr_y_past', 'etr_y_ma', 'diff_ma', 'roa_ma', 'lev_ma', 'intan_ma', 'ppe_ma', 'sale_ma', 'cash_holdings_ma', 'roa_past', 'lev_past', 'intan_past', 'ppe_past', 'sale_past', 'cash_holdings_past']

# %%
estimator = SVR(kernel='rbf', C=0.01, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)
estimator.fit(df.loc[:,pi_candidates].values, df.loc[:,"etr"].values.ravel())
result = permutation_importance(estimator, df.loc[:,pi_candidates].values, df.loc[:,"etr"].values.ravel(), n_repeats=3, scoring='neg_mean_squared_error', random_state=42, n_jobs=-1)
sorted_idx = result.importances_mean.argsort()

# %%
sorted_idx = sorted_idx[-20:]

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.boxplot(result.importances[sorted_idx].T,
           vert=False, labels=df.loc[:,pi_candidates].columns[sorted_idx])
ax.set_title("Permutation Importances")
fig.tight_layout()
plt.show()

# %%
pi_var = df.loc[:,pi_candidates].columns[sorted_idx].tolist()

# %%
estimator = SVR(kernel='rbf', C=0.01, epsilon=0.1, shrinking=True, cache_size=500, verbose=False, max_iter=-1)
estimator.fit(df.loc[:,pi_var].values, df.loc[:,"etr"].values.ravel())
result = permutation_importance(estimator, df.loc[:,pi_var].values, df.loc[:,"etr"].values.ravel(), n_repeats=3, scoring='neg_mean_squared_error', random_state=42, n_jobs=-1)
sorted_idx = result.importances_mean.argsort()

# %%
sorted_idx = sorted_idx[-10:]

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.boxplot(result.importances[sorted_idx].T,
           vert=False, labels=df.loc[:,pi_var].columns[sorted_idx])
ax.set_title("Permutation Importances")
fig.tight_layout()
plt.show()

# %%
pi_var_prim = df.loc[:,pi_var].columns[sorted_idx].tolist()

# %%
pi_var_prim
# Out:
# ['ni',
#  'lev_ma',
#  'rok',
#  'rr_per_sector',
#  'sale',
#  'WB_GDPgrowth',
#  'str',
#  'WB_GDPpc',
#  'etr_y_past',
#  'etr_y_ma']

# %% [markdown]
# ### Hyperparametes Tunning for each group of variables

# %%
param = {"C":[0.005, 0.01, 0.05, 0.1, 0.25], "epsilon":[0.005, 0.01, 0.05, 0.1], "kernel":["rbf"]}
mse = make_scorer(mean_squared_error, greater_is_better=True)

# %%
def cv_proc(var):
    model = SVR()
    grid_CV = GridSearchCV(model, param, cv=5, scoring=mse, return_train_score=True, n_jobs=-1)
    grid_CV.fit(df.loc[:,var].values, df.loc[:,"etr"].values.ravel())
    print(grid_CV.best_estimator_)
    print(grid_CV.best_score_)

# %%
cv_proc(br_features)
# Out:
# SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.005, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.02050896147528598

# %%
cv_proc(mi_features)
# Out:
# SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.02100854502826018

# %%
cv_proc(mi_features_25)
# Out:
# SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.021109140350410126

# %%
cv_proc(mi_features_35)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.021266260459285372

# %%
cv_proc(mi_features_50)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.021480124544892974

# %%
cv_proc(benchmark)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.021112205998240374

# %%
cv_proc(benchmark2)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.021004067521406718

# %%
cv_proc(sf_features)
# Out:
# SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.0204184599385606

# %%
cv_proc(sf_features2)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.020177018721990285

# %%
cv_proc(rfe_candidates_without_disc)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.021421724782342146

# %%
cv_proc(rfe_candidates)
# Out:
# SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.02066310216364966

# %%
cv_proc(pi_var_prim)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.020594118314571714

# %%
cv_proc(pi_var)
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# 0.02061476435456332

# %% [markdown]
# ### Final models comparison - winner obtaining

# %% [markdown]
# We would like to fight against data leakage in our CV, so we will treat it like a panel problem with a rolling window. We now based on our experience that this kind of approach is crucial to fight against overfitting.
#
# Sliding window:
#  * T: 2005 - 2008; V: 2009
#  * T: 2005 - 2009; V: 2010
#  * T: 2005 - 2010; V: 2011
#  * ...

# %%
df = df.sort_values(by="rok").reset_index(drop=True)

# %%
def proper_CV(x, y, model, display_res = False):
    train_score = list()
    valid_score = list()
    train_indexes = [0, 1452]
    valid_indexes = [1452, 1815]
    for i in range(0,6):
        train_x =  x[x.index.isin(range(train_indexes[0],train_indexes[1]))]
        train_y =  y[y.index.isin(range(train_indexes[0],train_indexes[1]))]
        valid_x =  x[x.index.isin(range(valid_indexes[0],valid_indexes[1]))]
        valid_y =  y[y.index.isin(range(valid_indexes[0],valid_indexes[1]))]

        model.fit(train_x.values, train_y.values.ravel())
        
        pred_y_train = model.predict(train_x.values)
        rmse = np.sqrt(mean_squared_error(train_y, pred_y_train))
        train_score.append(rmse)

        pred_y_val = model.predict(valid_x.values)
        rmse = np.sqrt(mean_squared_error(valid_y, pred_y_val))
        valid_score.append(rmse)
        
        train_indexes = [0, valid_indexes[1]]
        valid_indexes = [train_indexes[1], valid_indexes[1]+363]
    
    if display_res == True:
        view = pd.DataFrame([train_score, valid_score]).T.rename(columns = {0:"cv_train", 1:"cv_val"})
        display(view)
        return train_score, valid_score, view
    else:
        return train_score, valid_score

# %%
model = SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.005, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = br_features
cv_output0 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.134233  0.151183
# 1  0.135186  0.135500
# 2  0.134435  0.151313
# 3  0.136007  0.146419
# 4  0.136188  0.126274
# 5  0.135440  0.136285

# %%
model = SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = mi_features
cv_output1 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.132702  0.141898
# 1  0.133471  0.136166
# 2  0.133042  0.149741
# 3  0.135691  0.147250
# 4  0.135711  0.129298
# 5  0.134502  0.135628

# %%
model = SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = mi_features_25
cv_output2 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.131936  0.141598
# 1  0.132671  0.136225
# 2  0.132384  0.149925
# 3  0.134612  0.147863
# 4  0.134907  0.129809
# 5  0.133872  0.136911

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

var = mi_features_35
cv_output3 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.146095  0.134814
# 1  0.144374  0.135153
# 2  0.142954  0.148436
# 3  0.143574  0.147616
# 4  0.143316  0.131054
# 5  0.141933  0.136807

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

var = mi_features_50
cv_output4 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.147552  0.133295
# 1  0.145146  0.135665
# 2  0.143824  0.148595
# 3  0.144209  0.147920
# 4  0.144071  0.131237
# 5  0.142631  0.136876

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = benchmark
cv_output5 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.146596  0.132496
# 1  0.144070  0.135365
# 2  0.142615  0.148531
# 3  0.143075  0.148017
# 4  0.142786  0.131247
# 5  0.141155  0.135479

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = benchmark2
cv_output6 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.146509  0.132446
# 1  0.143672  0.135084
# 2  0.142299  0.147696
# 3  0.142964  0.146968
# 4  0.142471  0.130342
# 5  0.140921  0.134775

# %%
model = SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

var = sf_features
cv_output7 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.121479  0.135793
# 1  0.124027  0.141168
# 2  0.125163  0.151360
# 3  0.128583  0.147625
# 4  0.130098  0.129786
# 5  0.130188  0.134531

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

var = sf_features2
cv_output8 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.141995  0.132484
# 1  0.139530  0.130723
# 2  0.138448  0.147945
# 3  0.139721  0.145853
# 4  0.140273  0.127853
# 5  0.138805  0.132804

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = rfe_candidates_without_disc
cv_output9 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.147338  0.133335
# 1  0.144738  0.135666
# 2  0.143236  0.149261
# 3  0.144008  0.148871
# 4  0.143781  0.132081
# 5  0.142272  0.136938

# %%
model = SVR(C=0.25, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = rfe_candidates
cv_output10 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.128343  0.145131
# 1  0.129065  0.131564
# 2  0.128832  0.153142
# 3  0.132373  0.146240
# 4  0.132483  0.133438
# 5  0.131940  0.130063

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

var = pi_var_prim
cv_output11 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.142240  0.132031
# 1  0.140077  0.133167
# 2  0.139331  0.149107
# 3  0.140710  0.147362
# 4  0.141204  0.129784
# 5  0.139712  0.133866

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
var = pi_var
cv_output12 = proper_CV(df.loc[:,var], df.loc[:,"etr"], model, display_res=True)
# Out:
#    cv_train    cv_val
# 0  0.142806  0.131721
# 1  0.141106  0.133628
# 2  0.140296  0.148376
# 3  0.141001  0.145644
# 4  0.140918  0.129012
# 5  0.139669  0.133389

# %%
pd.DataFrame([cv_output0[2].mean().tolist(),
cv_output1[2].mean().tolist(), 
cv_output2[2].mean().tolist(),
cv_output3[2].mean().tolist(),
cv_output4[2].mean().tolist(),
cv_output5[2].mean().tolist(),
cv_output6[2].mean().tolist(),
cv_output7[2].mean().tolist(),
cv_output8[2].mean().tolist(),
cv_output9[2].mean().tolist(),
cv_output10[2].mean().tolist(),
cv_output11[2].mean().tolist(),
cv_output12[2].mean().tolist()
             ], columns=["train_mean", "test_mean"])
# Out:
#     train_mean  test_mean
# 0     0.135248   0.141162
# 1     0.134187   0.139997
# 2     0.133397   0.140388
# 3     0.143707   0.138980
# 4     0.144572   0.138931
# 5     0.143383   0.138522
# 6     0.143140   0.137885
# 7     0.126590   0.140044
# 8     0.139795   0.136277
# 9     0.144229   0.139359
# 10    0.130506   0.139930
# 11    0.140546   0.137553
# 12    0.140966   0.136961

# %%
pd.DataFrame([cv_output0[2].std().tolist(),
cv_output1[2].std().tolist(), 
cv_output2[2].std().tolist(),
cv_output3[2].std().tolist(),
cv_output4[2].std().tolist(),
cv_output5[2].std().tolist(),
cv_output6[2].std().tolist(),
cv_output7[2].std().tolist(),
cv_output8[2].std().tolist(),
cv_output9[2].std().tolist(),
cv_output10[2].std().tolist(),
cv_output11[2].std().tolist(),
cv_output12[2].std().tolist(),
             ], columns=["train_std", "test_std"])
# Out:
#     train_std  test_std
# 0    0.000799  0.010085
# 1    0.001320  0.007738
# 2    0.001239  0.007611
# 3    0.001417  0.007260
# 4    0.001668  0.007484
# 5    0.001833  0.007730
# 6    0.001884  0.007520
# 7    0.003576  0.008252
# 8    0.001260  0.008439
# 9    0.001731  0.007711
# 10   0.001950  0.009497
# 11   0.001070  0.008407
# 12   0.001053  0.008003

# %% [markdown]
# 8th models seems to be the best one! We see that our intuition was quite good - binary variables should be removed!

# %%
print(sf_features2)
# Out:
# Index(['diff', 'cfc', 'WB_GDPgrowth', 'WB_Inflation', 'sektor_industrials',
#        'sektor_materials', 'sektor_utilities', 'txt_cat_(-63.011, -34.811]',
#        'pi_cat_(-8975.0, -1.523]', 'pi_cat_(8108.5, inf]',
#        'str_cat_(0.28, inf]', 'dlc_cat_(42.262, 176.129]',
#        'dlc_cat_(176.129, 200.9]', 'capex_cat_(5451.0, inf]',
#        'revenue_cat_(0.174, 1248.817]', 'adv_cat_(0.3, 874.5]',
#        'diff_positive', 'etr_y_past', 'etr_y_ma', 'diff_ma'],
#       dtype='object')

# %% [markdown]
# ### Fit final model and save it

# %%
model = SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

model.fit(df.loc[:,sf_features2].values, df.loc[:,"etr"].values.ravel())
# Out:
# SVR(C=0.005, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
filename = 'final_models/svr.sav'

# %%
pickle.dump(model, open(filename, 'wb'))
