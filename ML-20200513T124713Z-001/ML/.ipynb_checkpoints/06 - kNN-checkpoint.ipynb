# %%
import pandas as pd
import numpy as np
import pickle
import statsmodels.api as sm

import matplotlib.pyplot as plt
plt.style.use('seaborn-ticks')
# %matplotlib inline

import gc
import math

# %%
medical = pd.read_pickle("data/medical.p")
print(medical.UCURNINS.unique())
medical["UCURNINS"] = (medical.UCURNINS=="Yes").astype(int)
print(medical.UCURNINS.unique())
features = ["UMARSTAT", "USATMED", "URELATE", "REGION", "FHOSP", "FDENT", "FEMER", "FDOCT", "UIMMSTAT", "UAGE", "U_FTPT", "U_WKSLY", "U_USHRS", "HOTHVAL", "HRETVAL", "HSSVAL", "HWSVAL", "UBRACE", "UEDUC3", "GENDER"]
levCols = []
numCols = []
for col in features:
    if medical[col].dtype==object:
        levCols.append(col)
    else:
        numCols.append(col)

# Binaryzacja zmiennych nominalnych
## one hot ncoding with pandas get_dummies
dummLev = pd.get_dummies(medical[levCols], drop_first=True)/2 # 0 or 0.5
dummLev.shape
medical2 = pd.concat([medical[numCols], dummLev], axis=1)
print(medical.shape, math.sqrt(medical.shape[0]))
# Out:
# ['Yes' 'No']
# [1 0]
# (35072, 29) 187.275198571514

# %% [markdown]
# At this stage we have our dataset prepared. With all nominal variables in binary form.
#
# We have around 35 k rows. That is a considerable amount so chosing $k=\sqrt{N}$ might be too high. Maybe lets start with 50.
#
# First we need to standarize our data.

# %%
np.sqrt(35000)
### 187 to high
# Out:
# 187.08286933869707

# %%
## z-score
medical2[numCols] = medical2[numCols].apply(lambda x: (x-x.mean())/x.std())
features = medical2.columns.tolist()

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn import neighbors

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=2018)
probs = []
indicies = []
aucs = []
bacc = []
accs = []
n_neighbors = 50
clf = neighbors.KNeighborsClassifier(n_neighbors, n_jobs=-1, p=2)
for train, test in kf.split(medical2.index.values):
    clf.fit(medical2.iloc[train][features].values, medical.iloc[train]["UCURNINS"].values)
    prob = clf.predict_proba(medical2.iloc[test][features].values)
    probs.append(prob)
    indicies.append(test)
    aucs.append(metrics.roc_auc_score(medical.iloc[test]["UCURNINS"].values, prob[:,1]))
    accs.append(metrics.accuracy_score(medical.iloc[test]["UCURNINS"].values, (prob[:,1]>0.5).astype(int)))
print(np.mean(aucs))
print(aucs)
print(np.mean(accs))
print(accs)
# Out:
# 0.803055263868815
# [0.8030964370369477, 0.8059743934949007, 0.7998959044062994, 0.8026520604752083, 0.8036575239307187]
# 0.8634521893998379
# [0.8624376336421953, 0.86928011404134, 0.8598517251211862, 0.8659823210721415, 0.8597091531223268]

# %%
n_neighbors = 25
clf = neighbors.KNeighborsClassifier(n_neighbors, n_jobs=-1, p=2)
aucs = []
bacc = []
accs = []
for train, test in kf.split(medical2.index.values):
    clf.fit(medical2.iloc[train][features].values, medical.iloc[train]["UCURNINS"].values)
    prob = clf.predict_proba(medical2.iloc[test][features].values)
    probs.append(prob)
    indicies.append(test)
    aucs.append(metrics.roc_auc_score(medical.iloc[test]["UCURNINS"].values, prob[:,1]))
    accs.append(metrics.accuracy_score(medical.iloc[test]["UCURNINS"].values, (prob[:,1]>0.5).astype(int)))
print(np.mean(aucs))
print(aucs)
print(np.mean(accs))
print(accs)

## We have drop 0.8 -> 0.79
## Lets go back to 50
# Out:
# 0.7920728510339776
# [0.7947005524710336, 0.7953938430879421, 0.7892516782026375, 0.7901133445237587, 0.7909048368845164]
# 0.8638799785623743
# [0.8628652886671418, 0.8662865288667142, 0.8599942971200456, 0.8666951810664385, 0.8635585970915313]

# %% [markdown]
# For now 50 seems to be the best value.
#
# Now lets see if changing our distance metric from Euclidesian to Manhatan distance is any better.

# %%
## p=1 to Manhattan distance
n_neighbors = 50
clf = neighbors.KNeighborsClassifier(n_neighbors, n_jobs=-1, p=1)
aucs = []
bacc = []
accs = []
for train, test in kf.split(medical2.index.values):
    clf.fit(medical2.iloc[train][features].values, medical.iloc[train]["UCURNINS"].values)
    prob = clf.predict_proba(medical2.iloc[test][features].values)
    probs.append(prob)
    indicies.append(test)
    aucs.append(metrics.roc_auc_score(medical.iloc[test]["UCURNINS"].values, prob[:,1]))
    accs.append(metrics.accuracy_score(medical.iloc[test]["UCURNINS"].values, (prob[:,1]>0.5).astype(int)))
print(np.mean(aucs))
print(aucs)
print(np.mean(accs))
print(accs)
## Now result jumped to 0.82
# Out:
# 0.821076843317331
# [0.8195131763312905, 0.823915780066403, 0.8216682109449127, 0.8182078855808872, 0.8220791636631617]
# 0.8655907084110975
# [0.8627227369921596, 0.8711332858161084, 0.8638437410892501, 0.8672654690618763, 0.8629883090960935]

# %% [markdown]
# Choosing a different metric did not change a lot. Lets see how much improvement can we get by chosing fewer variables.

# %%
## Maybe fewer variables!
## They are not selected accidently
feat2 = ["USATMED", "FDENT", "UEDUC3", "FDOCT", 'UMARSTAT_Married_live together','UIMMSTAT_Foreign-born, non-citizen',
 'UIMMSTAT_US-born citizen']
n_neighbors = 60
clf = neighbors.KNeighborsClassifier(n_neighbors, n_jobs=-1, p=1)
aucs = []
bacc = []
accs = []
for train, test in kf.split(medical2.index.values):
    clf.fit(medical2.iloc[train][feat2].values, medical.iloc[train]["UCURNINS"].values)
    prob = clf.predict_proba(medical2.iloc[test][feat2].values)
    probs.append(prob)
    indicies.append(test)
    aucs.append(metrics.roc_auc_score(medical.iloc[test]["UCURNINS"].values, prob[:,1]))
    accs.append(metrics.accuracy_score(medical.iloc[test]["UCURNINS"].values, (prob[:,1]>0.5).astype(int)))
print(np.mean(aucs))
print(aucs)
print(np.mean(accs))
print(accs)
# Out:
# 0.813470502974344
# [0.8121996863268072, 0.8178453045417236, 0.8113800587885188, 0.8119685169179094, 0.8139589482967611]
# 0.8688125876340183
# [0.867712045616536, 0.8748396293656451, 0.8656971770744226, 0.8675506130595951, 0.8682634730538922]

# %%
## Now there are a lot of libraries which ease choosing features
## Too much libraries -> you lose insight
## practical experience -> extremely important to do steps on your own

## In a loop add feature one by one
featuresCopy = features.copy()
selectdFeat = []
for k in range(10):
    results = []
    for oneFeat in featuresCopy:
        tempFeatures = selectdFeat + [oneFeat]
        n_neighbors = 60
        clf = neighbors.KNeighborsClassifier(n_neighbors, n_jobs=-1, p=1)
        aucs = []
        accs = []
        for train, test in kf.split(medical2.index.values):
            clf.fit(medical2.iloc[train][tempFeatures].values, medical.iloc[train]["UCURNINS"].values)
            prob = clf.predict_proba(medical2.iloc[test][tempFeatures].values)
            probs.append(prob)
            indicies.append(test)
            aucs.append(metrics.roc_auc_score(medical.iloc[test]["UCURNINS"].values, prob[:,1]))
            accs.append(metrics.accuracy_score(medical.iloc[test]["UCURNINS"].values, (prob[:,1]>0.5).astype(int)))
        print(tempFeatures)
        print(oneFeat, np.mean(aucs))
        results.append((np.mean(aucs), oneFeat))
    selectdFeat.append(sorted(results, key=lambda x: x[0], reverse=True)[0][1])
    featuresCopy.remove(sorted(results, key=lambda x: x[0], reverse=True)[0][1])
    
## Doing projects - try not to rely on libraries
# Out:
# ['USATMED']
# USATMED 0.5906214773341315
# ['URELATE']
# URELATE 0.5538231827433575
# ['FDENT']
# FDENT 0.7010216364174511
# ['FEMER']
# FEMER 0.4919991425814582
# ['FDOCT']
# FDOCT 0.6788271562686307
# ['UAGE']
# UAGE 0.600611041461456
# ['U_WKSLY']
# U_WKSLY 0.5746972464725293
# ['U_USHRS']
# U_USHRS 0.5439670337163166
# ['HOTHVAL']
# HOTHVAL 0.5017950169205008
# ['HRETVAL']
# HRETVAL 0.4940951815666589
# ['HSSVAL']
# HSSVAL 0.5035492147430869
# ['HWSVAL']
# HWSVAL 0.4950505533789718
# ['UEDUC3']
# UEDUC3 0.6737101106725388
# ['UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.4964851502042055
# ['UMARSTAT_Married_live together']
# UMARSTAT_Married_live together 0.6216816378509629
# ['UMARSTAT_Never married']
# UMARSTAT_Never married 0.44346211888369125
# ['UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.5123480364631912
# ['UMARSTAT_Separated']
# UMARSTAT_Separated 0.48781162429291525
# ['UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.4993195392413807
# ['UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.49922146945348544
# ['REGION_Northeast']
# REGION_Northeast 0.5328647357226544
# ['REGION_South']
# REGION_South 0.4374897398147297
# ['REGION_West']
# REGION_West 0.46916449958405665
# ['FHOSP_Yes']
# FHOSP_Yes 0.5129660428580608
# ['UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.5858277525316944
# ['UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.5896279328786075
# ['U_FTPT_Part-time']
# U_FTPT_Part-time 0.4740756660673916
# ['UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.5029976281701571
# ['UBRACE_Black']
# UBRACE_Black 0.4783552601100506
# ['UBRACE_White']
# UBRACE_White 0.5270167004587472
# ['GENDER_Male']
# GENDER_Male 0.4746820424116646
# ['FDENT', 'USATMED']
# USATMED 0.7130650721210486
# ['FDENT', 'URELATE']
# URELATE 0.7086810942563401
# ['FDENT', 'FEMER']
# FEMER 0.7029404205870454
# ['FDENT', 'FDOCT']
# FDOCT 0.742407727641942
# ['FDENT', 'UAGE']
# UAGE 0.7219412300822409
# ['FDENT', 'U_WKSLY']
# U_WKSLY 0.7121470694825944
# ['FDENT', 'U_USHRS']
# U_USHRS 0.706089753220873
# ['FDENT', 'HOTHVAL']
# HOTHVAL 0.694102478938287
# ['FDENT', 'HRETVAL']
# HRETVAL 0.6932399471740288
# ['FDENT', 'HSSVAL']
# HSSVAL 0.6894620503010079
# ['FDENT', 'HWSVAL']
# HWSVAL 0.698038101611399
# ['FDENT', 'UEDUC3']
# UEDUC3 0.7496193635119521
# ['FDENT', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.6952746372117622
# ['FDENT', 'UMARSTAT_Married_live together']
# UMARSTAT_Married_live together 0.7308192565263942
# ['FDENT', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.7083343163814757
# ['FDENT', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.7016175397828576
# ['FDENT', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.701445173989832
# ['FDENT', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.7009171586618589
# ['FDENT', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.7008969794214472
# ['FDENT', 'REGION_Northeast']
# REGION_Northeast 0.7067046115104558
# ['FDENT', 'REGION_South']
# REGION_South 0.7024924532212582
# ['FDENT', 'REGION_West']
# REGION_West 0.6953540705063326
# ['FDENT', 'FHOSP_Yes']
# FHOSP_Yes 0.6985925535504494
# ['FDENT', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.7281306183712637
# ['FDENT', 'UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.7256342909775514
# ['FDENT', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.7007552178656102
# ['FDENT', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.700595356131654
# ['FDENT', 'UBRACE_Black']
# UBRACE_Black 0.6978132030294528
# ['FDENT', 'UBRACE_White']
# UBRACE_White 0.7031453524721825
# ['FDENT', 'GENDER_Male']
# GENDER_Male 0.6918258154938199
# ['FDENT', 'UEDUC3', 'USATMED']
# USATMED 0.764017219433343
# ['FDENT', 'UEDUC3', 'URELATE']
# URELATE 0.7518267530883425
# ['FDENT', 'UEDUC3', 'FEMER']
# FEMER 0.7395004140885638
# ['FDENT', 'UEDUC3', 'FDOCT']
# FDOCT 0.7770971854377209
# ['FDENT', 'UEDUC3', 'UAGE']
# UAGE 0.7597472797317625
# ['FDENT', 'UEDUC3', 'U_WKSLY']
# U_WKSLY 0.7625932436048243
# ['FDENT', 'UEDUC3', 'U_USHRS']
# U_USHRS 0.7504104141799861
# ['FDENT', 'UEDUC3', 'HOTHVAL']
# HOTHVAL 0.7444375478153871
# ['FDENT', 'UEDUC3', 'HRETVAL']
# HRETVAL 0.751268311412824
# ['FDENT', 'UEDUC3', 'HSSVAL']
# HSSVAL 0.7477783602678427
# ['FDENT', 'UEDUC3', 'HWSVAL']
# HWSVAL 0.745453322387967
# ['FDENT', 'UEDUC3', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.7501222434104997
# ['FDENT', 'UEDUC3', 'UMARSTAT_Married_live together']
# UMARSTAT_Married_live together 0.7658208745131982
# ['FDENT', 'UEDUC3', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.7575907737934713
# ['FDENT', 'UEDUC3', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.7537955971321741
# ['FDENT', 'UEDUC3', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.7502614064137388
# ['FDENT', 'UEDUC3', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.7493236199281139
# ['FDENT', 'UEDUC3', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.7500814043625801
# ['FDENT', 'UEDUC3', 'REGION_Northeast']
# REGION_Northeast 0.7471043687575212
# ['FDENT', 'UEDUC3', 'REGION_South']
# REGION_South 0.7508157614832867
# ['FDENT', 'UEDUC3', 'REGION_West']
# REGION_West 0.749815903171138
# ['FDENT', 'UEDUC3', 'FHOSP_Yes']
# FHOSP_Yes 0.751756528881719
# ['FDENT', 'UEDUC3', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.7554262474928868
# ['FDENT', 'UEDUC3', 'UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.7544246431223233
# ['FDENT', 'UEDUC3', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.755243066233455
# ['FDENT', 'UEDUC3', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.7481163541886613
# ['FDENT', 'UEDUC3', 'UBRACE_Black']
# UBRACE_Black 0.7493174223530094
# ['FDENT', 'UEDUC3', 'UBRACE_White']
# UBRACE_White 0.7491413476943986
# ['FDENT', 'UEDUC3', 'GENDER_Male']
# GENDER_Male 0.7435014261431323
# ['FDENT', 'UEDUC3', 'FDOCT', 'USATMED']
# USATMED 0.7909108614459736
# ['FDENT', 'UEDUC3', 'FDOCT', 'URELATE']
# URELATE 0.7787645368567093
# ['FDENT', 'UEDUC3', 'FDOCT', 'FEMER']
# FEMER 0.7742767959019077
# ['FDENT', 'UEDUC3', 'FDOCT', 'UAGE']
# UAGE 0.7890457498568209
# ['FDENT', 'UEDUC3', 'FDOCT', 'U_WKSLY']
# U_WKSLY 0.7882564777658985
# ['FDENT', 'UEDUC3', 'FDOCT', 'U_USHRS']
# U_USHRS 0.7818672401641628
# ['FDENT', 'UEDUC3', 'FDOCT', 'HOTHVAL']
# HOTHVAL 0.7740421622618875
# ['FDENT', 'UEDUC3', 'FDOCT', 'HRETVAL']
# HRETVAL 0.778175755371009
# ['FDENT', 'UEDUC3', 'FDOCT', 'HSSVAL']
# HSSVAL 0.7760451921150404
# ['FDENT', 'UEDUC3', 'FDOCT', 'HWSVAL']
# HWSVAL 0.7772550846517701
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.7779793886331179
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together']
# UMARSTAT_Married_live together 0.79276064317008
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.782253371552879
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.7797427262114642
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.7770669311386547
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.777802199134072
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.7775687557834591
# ['FDENT', 'UEDUC3', 'FDOCT', 'REGION_Northeast']
# REGION_Northeast 0.7758458558690388
# ['FDENT', 'UEDUC3', 'FDOCT', 'REGION_South']
# REGION_South 0.7784555741756066
# ['FDENT', 'UEDUC3', 'FDOCT', 'REGION_West']
# REGION_West 0.7769489807267063
# ['FDENT', 'UEDUC3', 'FDOCT', 'FHOSP_Yes']
# FHOSP_Yes 0.7767180053319838
# ['FDENT', 'UEDUC3', 'FDOCT', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.7856159004197856
# ['FDENT', 'UEDUC3', 'FDOCT', 'UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.7833150332379069
# ['FDENT', 'UEDUC3', 'FDOCT', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.7813977192361521
# ['FDENT', 'UEDUC3', 'FDOCT', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.7771825541098643
# ['FDENT', 'UEDUC3', 'FDOCT', 'UBRACE_Black']
# UBRACE_Black 0.7748250888881374
# ['FDENT', 'UEDUC3', 'FDOCT', 'UBRACE_White']
# UBRACE_White 0.7751855635785129
# ['FDENT', 'UEDUC3', 'FDOCT', 'GENDER_Male']
# GENDER_Male 0.7755850337235939
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED']
# USATMED 0.8050288014284692
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'URELATE']
# URELATE 0.7941630660394908
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'FEMER']
# FEMER 0.7930230940200791
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UAGE']
# UAGE 0.801753043625751
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'U_WKSLY']
# U_WKSLY 0.8019586333756582
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'U_USHRS']
# U_USHRS 0.7980542270266747
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'HOTHVAL']
# HOTHVAL 0.792542518862683
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'HRETVAL']
# HRETVAL 0.7956689296782228
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'HSSVAL']
# HSSVAL 0.7941564301962643
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'HWSVAL']
# HWSVAL 0.7935941758911995
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.793180940279356
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.7927611868852871
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.7932003004832018
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.7925643012250998
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.7931545006169987
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.7932834522925682
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'REGION_Northeast']
# REGION_Northeast 0.7950042049452578
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'REGION_South']
# REGION_South 0.7962482777841023
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'REGION_West']
# REGION_West 0.7930911928719732
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'FHOSP_Yes']
# FHOSP_Yes 0.7915122569358781
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.8007020179989841
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.8013765129764107
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.7965173771661554
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.7924830517558227
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UBRACE_Black']
# UBRACE_Black 0.7923898284968813
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'UBRACE_White']
# UBRACE_White 0.7940898208075688
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'GENDER_Male']
# GENDER_Male 0.7939209555128276
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'URELATE']
# URELATE 0.804528555781259
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'FEMER']
# FEMER 0.8048332031271279
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UAGE']
# UAGE 0.8110823017654718
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY']
# U_WKSLY 0.8122221629093846
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_USHRS']
# U_USHRS 0.8051290220000731
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'HOTHVAL']
# HOTHVAL 0.8039637627832976
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'HRETVAL']
# HRETVAL 0.8053344650786048
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'HSSVAL']
# HSSVAL 0.8039554710801801
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'HWSVAL']
# HWSVAL 0.8040723448670957
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.8055053766693367
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.8059698622620018
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.8066603962827354
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.8057833752528593
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.8050707244524427
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.8059016468853439
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'REGION_Northeast']
# REGION_Northeast 0.8066658378240481
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'REGION_South']
# REGION_South 0.8088663360534405
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'REGION_West']
# REGION_West 0.805715393291915
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'FHOSP_Yes']
# FHOSP_Yes 0.8044869614014967
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.8109607341654368
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.8110461259553862
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.8080817026149211
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.8054849837128565
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UBRACE_Black']
# UBRACE_Black 0.8053316593731786
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'UBRACE_White']
# UBRACE_White 0.8061712015063284
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'GENDER_Male']
# GENDER_Male 0.8052960260063975
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'URELATE']
# URELATE 0.8112902815973877
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'FEMER']
# FEMER 0.8107964288598029
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE']
# UAGE 0.8169697888008571
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'U_USHRS']
# U_USHRS 0.811057656807017
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'HOTHVAL']
# HOTHVAL 0.8113080355616068
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'HRETVAL']
# HRETVAL 0.811628391159469
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'HSSVAL']
# HSSVAL 0.808198452671711
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'HWSVAL']
# HWSVAL 0.8116383421285807
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.8122381552327157
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.8125865717210103
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.8130017677892768
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.8119936001748329
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.812167241978543
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.8123717867838216
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'REGION_Northeast']
# REGION_Northeast 0.810902332346263
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'REGION_South']
# REGION_South 0.8148803191340626
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'REGION_West']
# REGION_West 0.8113861710506706
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'FHOSP_Yes']
# FHOSP_Yes 0.8118806020856152
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.8162067793262263
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.8165422024897218
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.8129868937823088
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.8115319593029786
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UBRACE_Black']
# UBRACE_Black 0.8127834607399317
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UBRACE_White']
# UBRACE_White 0.812906829182733
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'GENDER_Male']
# GENDER_Male 0.811589209853091
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'URELATE']
# URELATE 0.8163225160016202
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'FEMER']
# FEMER 0.8156383052016032
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'U_USHRS']
# U_USHRS 0.8190966647242695
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'HOTHVAL']
# HOTHVAL 0.8157634222435665
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'HRETVAL']
# HRETVAL 0.8169709561305464
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'HSSVAL']
# HSSVAL 0.8147478439580897
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'HWSVAL']
# HWSVAL 0.8143633030925592
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.816834618807472
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.8169284264242895
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.8168848528122394
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.81675731364945
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.8169010434682369
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.8169978647241335
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'REGION_Northeast']
# REGION_Northeast 0.8176512526962781
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'REGION_South']
# REGION_South 0.8182107535721878
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'REGION_West']
# REGION_West 0.8157138274098956
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'FHOSP_Yes']
# FHOSP_Yes 0.817013601787232
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.8205006338815917
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen']
# UIMMSTAT_US-born citizen 0.8213209895312265
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.8183347962970409
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.8169206381895089
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UBRACE_Black']
# UBRACE_Black 0.8169299044292988
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UBRACE_White']
# UBRACE_White 0.8173564885811148
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'GENDER_Male']
# GENDER_Male 0.8158541076986289
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'URELATE']
# URELATE 0.8198249603835641
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'FEMER']
# FEMER 0.8202522022310216
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'U_USHRS']
# U_USHRS 0.8224021726068299
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'HOTHVAL']
# HOTHVAL 0.8200717639675947
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'HRETVAL']
# HRETVAL 0.8212636249299262
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'HSSVAL']
# HSSVAL 0.818868924392868
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'HWSVAL']
# HWSVAL 0.8191723070290283
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.8212769428451268
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.8208423495203963
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.8210356150047012
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.8211842138771177
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.8211862470970465
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.8211803425887407
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_Northeast']
# REGION_Northeast 0.8218562922370722
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South']
# REGION_South 0.8231513416118567
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_West']
# REGION_West 0.8198797607263988
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'FHOSP_Yes']
# FHOSP_Yes 0.820825519388373
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UIMMSTAT_Foreign-born, non-citizen']
# UIMMSTAT_Foreign-born, non-citizen 0.8231283402451043
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'U_FTPT_Part-time']
# U_FTPT_Part-time 0.8222652988918913
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UBRACE_Asian/Pacific Islander']
# UBRACE_Asian/Pacific Islander 0.8208778164099944
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UBRACE_Black']
# UBRACE_Black 0.8214279977152336
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'UBRACE_White']
# UBRACE_White 0.8219315494987327
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'GENDER_Male']
# GENDER_Male 0.8204586769014945
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'URELATE']
# URELATE 0.8228398863877328
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'FEMER']
# FEMER 0.8229744885573378
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'U_USHRS']
# U_USHRS 0.8260001061098199
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'HOTHVAL']
# HOTHVAL 0.8225107135179929
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'HRETVAL']
# HRETVAL 0.822539704591222
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'HSSVAL']
# HSSVAL 0.8209616915565741
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'HWSVAL']
# HWSVAL 0.8226043547378442
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'UMARSTAT_Married, do not live together']
# UMARSTAT_Married, do not live together 0.8233378245378763
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'UMARSTAT_Never married']
# UMARSTAT_Never married 0.8226390467526343
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'UMARSTAT_Partnership']
# UMARSTAT_Partnership 0.8225224309099687
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'UMARSTAT_Separated']
# UMARSTAT_Separated 0.8227583025156464
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'UMARSTAT_Unknown']
# UMARSTAT_Unknown 0.8232181407693637
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'UMARSTAT_Widowed']
# UMARSTAT_Widowed 0.8229670661018116
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'REGION_Northeast']
# REGION_Northeast 0.8230205470758147
# ['FDENT', 'UEDUC3', 'FDOCT', 'UMARSTAT_Married_live together', 'USATMED', 'U_WKSLY', 'UAGE', 'UIMMSTAT_US-born citizen', 'REGION_South', 'REGION_West']
# REGION_West 0.8239790340611618
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9f7eca955dd7> in <module>()
#      16         for train, test in kf.split(medical2.index.values):
#      17             clf.fit(medical2.iloc[train][tempFeatures].values, medical.iloc[train]["UCURNINS"].values)
# ---> 18             prob = clf.predict_proba(medical2.iloc[test][tempFeatures].values)
#      19             probs.append(prob)
#      20             indicies.append(test)
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\neighbors\classification.py in predict_proba(self, X)
#     188         X = check_array(X, accept_sparse='csr')
#     189
# --> 190         neigh_dist, neigh_ind = self.kneighbors(X)
#     191
#     192         classes_ = self.classes_
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\neighbors\base.py in kneighbors(self, X, n_neighbors, return_distance)
#     383                 delayed(self._tree.query, check_pickle=False)(
#     384                     X[s], n_neighbors, return_distance)
# --> 385                 for s in gen_even_slices(X.shape[0], n_jobs)
#     386             )
#     387             if return_distance:
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\externals\joblib\parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\multiprocessing\pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\multiprocessing\pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# c:\users\michal_schudnij\appdata\local\programs\python\python36-32\lib\threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# As we can see the results is not much worse. Additionally for fairly large datasets our estimator is rather stable with different values of $k$.

# %% [markdown]
# ## Exercises 6
# ### Exercise 6.1
#
# Import titanic dataset, divide it into training and test data. Apply the KNN method to predict the value of the variable ‘survived’, test a few values of parameter k. Check whether the rescaling of variables allows to get better forecasts in the test sample.
#
# ### Exercise 6.2
#
# Find the optimal value for the parameter k using cross validation.
#
# ### Exercise 6.3
#
# Calculate the prediction error on the train and test sample for k = 1, 2, …. 100, and plot results. What conclusions can be drawn from this result?
